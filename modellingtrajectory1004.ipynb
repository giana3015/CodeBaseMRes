# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy.matlib
from matplotlib.widgets import Slider
from mpl_toolkits.mplot3d import Axes3D
from ipywidgets import interact, IntSlider, fixed

# %%
from ratinabox.Environment import Environment
from ratinabox.Agent import Agent

# %%
from network_utils import (
    gaussian, create3Dplot, create2Dplot, show_slice,
    plot_all_sensory_fields, plot_sensory_input_subplots,
    plot_initial_activation, plot_normalised_sensory_grid,
    plot_final_activation, generate_evenly_spaced_centers,
    generate_circular_trajectory, generate_edge_to_edge_trajectory,
    plot_trajectory_over_PC_idx, plot_trajectory_over_PC_idx, view_bump_with_slider_3D, 
    show_bump_3D, plot_maze_over_PC_idx
)

# %%
# === Step 1: Initialise network parameters and matrices === #

# Grid and network dimensions
rows = 10
cols = 10
nCells = rows * cols

# Sensory and recurrent configuration
nSensoryCells = 50
Sigma = 2.5                 # Spread of the Gaussian tuning curve
NetThreshold = 0.7       # Threshold for activation
nIterationsPerTimestep = 10  # Recurrent iterations per timestep
blend_factor = 0.9          # Influence of new input vs. previous state

# Allocate memory for the recurrent weight matrix
weightsMat = np.zeros((rows, cols, nCells))

# Create an index grid for place cells
PC_idx = np.arange(nCells).reshape(rows, cols)

# %% [markdown]
# # Create environment without any boundary
# # Step 1: Create environment with full 1x1 boundary
# env = Environment(params={
#     "boundary": [[0, 0], [0, 1], [1, 1], [1, 0]],  # full square
#     "boundary_conditions": "solid"
# })
#
# # Step 2: Maze parameters
# n_arms = 8
# arm_length = 0.48        # How far arms extend
# arm_width = 0.1        # Width of arms
# gap = 0.12               # Gap at center to avoid wall overlap
# center = np.array([0.5, 0.5])  # Center of environment
#
# # Step 3: Add radial arms with capped ends
# angles = np.linspace(0, 2 * np.pi, n_arms, endpoint=False)
#
# for angle in angles:
#     arm_dir = np.array([np.cos(angle), np.sin(angle)])
#     offset = np.array([-np.sin(angle), np.cos(angle)]) * (arm_width / 2)
#
#     # Start/end points with gap
#     start1 = center + arm_dir * gap + offset
#     end1 = center + arm_dir * arm_length + offset
#     start2 = center + arm_dir * gap - offset
#     end2 = center + arm_dir * arm_length - offset
#
#     # Side walls
#     env.add_wall([start1.tolist(), end1.tolist()])
#     env.add_wall([start2.tolist(), end2.tolist()])
#
#     # Cap wall
#     cap_start = end1
#     cap_end = end2
#     env.add_wall([cap_start.tolist(), cap_end.tolist()])

# %% [markdown]
# plot_maze_over_PC_idx(env, PC_idx)

# %% [markdown]
# # === Step 3: Create agent and simulate motion === #
# agent = Agent(env)
#
# agent.pos = center.copy()
# Agent.speed_mean = 0.08 #m/s
# Agent.speed_coherence_time = 0.7
# Agent.rotation_velocity_std = 120 * np.pi/180 #radians
# Agent.rotational_velocity_coherence_time = 0.08
#
# # Simulate for 10 seconds (100 steps)
# agent.update(Tmax=10.0, dt=0.1)
#
# # === Step 4: Extract and convert trajectory === #
# positions = np.array(agent.history["pos"])
# x_idx = np.clip((positions[:, 0] * cols).astype(int), 0, cols - 1)
# y_idx = np.clip((positions[:, 1] * rows).astype(int), 0, rows - 1)
# trajectory_positions = list(zip(y_idx, x_idx))
#
# print(f"Unique positions visited: {np.unique(positions, axis=0).shape[0]}")
#
# # === Step 5: Plot function === #
# def plot_maze_over_PC_idx(env, PC_idx, trajectory=None, show_indices=False,
#                           maze_color='blue', traj_color='red', lw=2):
#     rows, cols = PC_idx.shape
#     plt.figure(figsize=(8, 6))
#     plt.imshow(PC_idx, cmap='Greys', interpolation='none', origin='upper')
#     plt.title('Maze with Trajectory Over Place Cell Grid')
#
#     if show_indices:
#         for r in range(rows):
#             for c in range(cols):
#                 plt.text(c, r, f"{PC_idx[r, c]}", ha='center', va='center',
#                          fontsize=6, color='black')
#
#     for wall in env.walls:
#         (x0, y0), (x1, y1) = wall
#         x0_scaled, x1_scaled = x0 * (cols - 1), x1 * (cols - 1)
#         y0_scaled, y1_scaled = y0 * (rows - 1), y1 * (rows - 1)
#         plt.plot([x0_scaled, x1_scaled], [y0_scaled, y1_scaled],
#                  color=maze_color, linewidth=lw)
#
#     # Plot trajectory if provided
#     if trajectory:
#         ys, xs = zip(*trajectory)
#         plt.plot(xs, ys, marker='o', linestyle='-', color=traj_color,
#                  label='Trajectory', markersize=3)
#         plt.legend(loc='upper left')  # <---- Move legend to top-left
#
#     plt.xlabel("X (columns)")
#     plt.ylabel("Y (rows)")
#     plt.gca().invert_yaxis()
#     plt.tight_layout()
#     plt.show()
# # === Step 6: Plot everything === #
# plot_maze_over_PC_idx(env, PC_idx, trajectory_positions)

# %%
# Load the data
data = np.load("sargolini.npz")
positions = data['pos']   # shape: (T, 2)
times = data['t']

# Limit to first 50 timesteps
positions = positions[:1000]



# Convert continuous positions to discrete grid indices
x_norm = np.clip((positions[:, 0] * cols).astype(int), 0, cols - 1)
y_norm = np.clip((positions[:, 1] * rows).astype(int), 0, rows - 1)

# Create trajectory as list of (row, col)
trajectory_positions = list(zip(y_norm, x_norm))

# Plot the trajectory over the place cell grid
plot_trajectory_over_PC_idx(trajectory_positions, PC_idx)

# %%
# === Step 2: Initialise the recurrent weights matrix === #
# Each cell has a weight of 1 with itself and 0.5 with its immediate neighbours

weightsMat = np.zeros((rows, cols, nCells))  # Reset in case already defined

for k in range(nCells):
    # Get the (row, col) location of the k-th place cell
    r, c = np.where(PC_idx == k)
    r, c = r[0], c[0]

    # Assign weight of 1 to itself
    weightsMat[r, c, k] = 1.0

    # Assign weight of 0.5 to immediate neighbors (up, down, left, right)
    for dr, dc in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
        nr, nc = r + dr, c + dc
        if 0 <= nr < rows and 0 <= nc < cols:
            weightsMat[nr, nc, k] = 0.5

# %%
# Step 4: Create a sheet of sensory cells with Gaussian firing fields
SensoryFiringFields = np.zeros((rows, cols, nSensoryCells))

# Generate center positions
centers = generate_evenly_spaced_centers(rows, cols, nSensoryCells)

# Create coordinate grid
X, Y = np.meshgrid(np.arange(rows), np.arange(cols))

# Compute Gaussian firing fields
for i, (cx, cy) in enumerate(centers):
    SensoryFiringFields[:, :, i] = gaussian(X, Y, cx, cy, Sigma)

# %% [markdown]
# # Plot all sensory fields using the saved utility function
# plot_all_sensory_fields(SensoryFiringFields, PC_idx)

# %%
# STEP 5: Create a weights matrix between the sensory cells and attractor cells
sensoryWeights = np.zeros((nSensoryCells, nCells))

# Iterate over each place cell
for cell in range(nCells):
    r, c = np.where(PC_idx == cell) # find the position of the cell in the PC sheet

    # Extract firing rates from all sensory cells at this location
    sensoryWeights[:, cell] = SensoryFiringFields[r, c,:]


print("sensory Weights matrix shape:", sensoryWeights.shape)
# Out:
# sensory Weights matrix shape: (50, 100)

# %%
sensoryInputGrids = []  # to store (sensoryInputGridNormalised, pcRow, pcCol, timestep)

for t, (pcRow, pcCol) in enumerate(trajectory_positions):
    print(f"\n--- Timestep {t+1}: Position ({pcRow}, {pcCol}) ---")

    # Step 1: Find the sensory activity at that position
    currentSensoryActivity = SensoryFiringFields[pcRow, pcCol, :]

    # Step 2: Transpose to column vector
    currentSensoryActivity = np.transpose([currentSensoryActivity])

    # Step 3: Replicate across columns to match the weight matrix shape
    currentSensoryActivity = np.matlib.repmat(currentSensoryActivity, 1, nCells)

    # Step 4: Elementwise multiply and sum to get final sensory input
    sensoryInput = currentSensoryActivity * sensoryWeights
    sensoryInput = np.sum(sensoryInput, axis=0)
    sensoryInput = sensoryInput * 40
      # Scale the input

    # Step 5: Reshape into 2D grid
    sensoryInputGrid = sensoryInput.reshape(rows, cols)

    # Step 6: Normalise the grid for visualisation or comparison
    sensoryInputGridNormalised = sensoryInputGrid / np.max(sensoryInputGrid)

    # Store the normalised grid with the PC location and timestep
    sensoryInputGrids.append((sensoryInputGridNormalised, pcRow, pcCol, t+1))

    # You can now use sensoryInputGridNormalised in your attractor update loop
# Out:
# --- Timestep 1: Position (2, 8) ---
#
# --- Timestep 2: Position (2, 8) ---
#
# --- Timestep 3: Position (2, 8) ---
#
# --- Timestep 4: Position (2, 8) ---
#
# --- Timestep 5: Position (2, 8) ---
#
# --- Timestep 6: Position (2, 8) ---
#
# --- Timestep 7: Position (2, 8) ---
#
# --- Timestep 8: Position (2, 8) ---
#
# --- Timestep 9: Position (2, 8) ---
#
# --- Timestep 10: Position (2, 8) ---
#
# --- Timestep 11: Position (2, 8) ---
#
# --- Timestep 12: Position (2, 8) ---
#
# --- Timestep 13: Position (2, 8) ---
#
# --- Timestep 14: Position (1, 8) ---
#
# --- Timestep 15: Position (1, 8) ---
#
# --- Timestep 16: Position (1, 8) ---
#
# --- Timestep 17: Position (1, 8) ---
#
# --- Timestep 18: Position (1, 8) ---
#
# --- Timestep 19: Position (1, 8) ---
#
# --- Timestep 20: Position (1, 8) ---
#
# --- Timestep 21: Position (1, 8) ---
#
# --- Timestep 22: Position (1, 8) ---
#
# --- Timestep 23: Position (1, 8) ---
#
# --- Timestep 24: Position (1, 8) ---
#
# --- Timestep 25: Position (1, 8) ---
#
# --- Timestep 26: Position (1, 8) ---
#
# --- Timestep 27: Position (1, 8) ---
#
# --- Timestep 28: Position (1, 7) ---
#
# --- Timestep 29: Position (1, 7) ---
#
# --- Timestep 30: Position (1, 7) ---
#
# --- Timestep 31: Position (1, 7) ---
#
# --- Timestep 32: Position (1, 7) ---
#
# --- Timestep 33: Position (1, 7) ---
#
# --- Timestep 34: Position (1, 7) ---
#
# --- Timestep 35: Position (1, 8) ---
#
# --- Timestep 36: Position (1, 8) ---
#
# --- Timestep 37: Position (1, 8) ---
#
# --- Timestep 38: Position (1, 8) ---
#
# --- Timestep 39: Position (1, 8) ---
#
# --- Timestep 40: Position (1, 8) ---
#
# --- Timestep 41: Position (1, 8) ---
#
# --- Timestep 42: Position (1, 8) ---
#
# --- Timestep 43: Position (1, 8) ---
#
# --- Timestep 44: Position (1, 8) ---
#
# --- Timestep 45: Position (1, 8) ---
#
# --- Timestep 46: Position (1, 8) ---
#
# --- Timestep 47: Position (1, 8) ---
#
# --- Timestep 48: Position (1, 8) ---
#
# --- Timestep 49: Position (1, 8) ---
#
# --- Timestep 50: Position (1, 8) ---
#
# --- Timestep 51: Position (1, 8) ---
#
# --- Timestep 52: Position (1, 8) ---
#
# --- Timestep 53: Position (1, 8) ---
#
# --- Timestep 54: Position (1, 8) ---
#
# --- Timestep 55: Position (1, 8) ---
#
# --- Timestep 56: Position (1, 8) ---
#
# --- Timestep 57: Position (1, 8) ---
#
# --- Timestep 58: Position (1, 8) ---
#
# --- Timestep 59: Position (1, 8) ---
#
# --- Timestep 60: Position (1, 8) ---
#
# --- Timestep 61: Position (1, 8) ---
#
# --- Timestep 62: Position (1, 8) ---
#
# --- Timestep 63: Position (1, 8) ---
#
# --- Timestep 64: Position (1, 8) ---
#
# --- Timestep 65: Position (1, 8) ---
#
# --- Timestep 66: Position (1, 8) ---
#
# --- Timestep 67: Position (1, 8) ---
#
# --- Timestep 68: Position (1, 8) ---
#
# --- Timestep 69: Position (1, 8) ---
#
# --- Timestep 70: Position (0, 8) ---
#
# --- Timestep 71: Position (0, 8) ---
#
# --- Timestep 72: Position (0, 8) ---
#
# --- Timestep 73: Position (0, 8) ---
#
# --- Timestep 74: Position (0, 8) ---
#
# --- Timestep 75: Position (0, 8) ---
#
# --- Timestep 76: Position (0, 8) ---
#
# --- Timestep 77: Position (0, 8) ---
#
# --- Timestep 78: Position (0, 9) ---
#
# --- Timestep 79: Position (0, 9) ---
#
# --- Timestep 80: Position (0, 9) ---
#
# --- Timestep 81: Position (0, 9) ---
#
# --- Timestep 82: Position (0, 9) ---
#
# --- Timestep 83: Position (0, 9) ---
#
# --- Timestep 84: Position (0, 9) ---
#
# --- Timestep 85: Position (0, 9) ---
#
# --- Timestep 86: Position (0, 9) ---
#
# --- Timestep 87: Position (0, 9) ---
#
# --- Timestep 88: Position (0, 9) ---
#
# --- Timestep 89: Position (0, 9) ---
#
# --- Timestep 90: Position (0, 9) ---
#
# --- Timestep 91: Position (0, 9) ---
#
# --- Timestep 92: Position (0, 9) ---
#
# --- Timestep 93: Position (0, 9) ---
#
# --- Timestep 94: Position (1, 9) ---
#
# --- Timestep 95: Position (1, 9) ---
#
# --- Timestep 96: Position (1, 9) ---
#
# --- Timestep 97: Position (1, 9) ---
#
# --- Timestep 98: Position (1, 9) ---
#
# --- Timestep 99: Position (1, 9) ---
#
# --- Timestep 100: Position (1, 9) ---
#
# --- Timestep 101: Position (1, 9) ---
#
# --- Timestep 102: Position (1, 9) ---
#
# --- Timestep 103: Position (1, 9) ---
#
# --- Timestep 104: Position (1, 9) ---
#
# --- Timestep 105: Position (1, 9) ---
#
# --- Timestep 106: Position (1, 9) ---
#
# --- Timestep 107: Position (1, 9) ---
#
# --- Timestep 108: Position (1, 9) ---
#
# --- Timestep 109: Position (1, 9) ---
#
# --- Timestep 110: Position (1, 9) ---
#
# --- Timestep 111: Position (1, 9) ---
#
# --- Timestep 112: Position (1, 9) ---
#
# --- Timestep 113: Position (1, 9) ---
#
# --- Timestep 114: Position (1, 9) ---
#
# --- Timestep 115: Position (1, 9) ---
#
# --- Timestep 116: Position (1, 9) ---
#
# --- Timestep 117: Position (1, 9) ---
#
# --- Timestep 118: Position (1, 9) ---
#
# --- Timestep 119: Position (1, 9) ---
#
# --- Timestep 120: Position (1, 9) ---
#
# --- Timestep 121: Position (1, 9) ---
#
# --- Timestep 122: Position (1, 9) ---
#
# --- Timestep 123: Position (1, 9) ---
#
# --- Timestep 124: Position (1, 9) ---
#
# --- Timestep 125: Position (1, 9) ---
#
# --- Timestep 126: Position (1, 9) ---
#
# --- Timestep 127: Position (1, 9) ---
#
# --- Timestep 128: Position (1, 9) ---
#
# --- Timestep 129: Position (1, 9) ---
#
# --- Timestep 130: Position (1, 9) ---
#
# --- Timestep 131: Position (1, 9) ---
#
# --- Timestep 132: Position (1, 9) ---
#
# --- Timestep 133: Position (1, 9) ---
#
# --- Timestep 134: Position (1, 9) ---
#
# --- Timestep 135: Position (1, 9) ---
#
# --- Timestep 136: Position (1, 9) ---
#
# --- Timestep 137: Position (1, 9) ---
#
# --- Timestep 138: Position (1, 9) ---
#
# --- Timestep 139: Position (1, 9) ---
#
# --- Timestep 140: Position (1, 9) ---
#
# --- Timestep 141: Position (1, 9) ---
#
# --- Timestep 142: Position (1, 9) ---
#
# --- Timestep 143: Position (1, 9) ---
#
# --- Timestep 144: Position (1, 9) ---
#
# --- Timestep 145: Position (1, 9) ---
#
# --- Timestep 146: Position (1, 9) ---
#
# --- Timestep 147: Position (1, 9) ---
#
# --- Timestep 148: Position (1, 9) ---
#
# --- Timestep 149: Position (1, 9) ---
#
# --- Timestep 150: Position (1, 9) ---
#
# --- Timestep 151: Position (1, 9) ---
#
# --- Timestep 152: Position (1, 9) ---
#
# --- Timestep 153: Position (1, 9) ---
#
# --- Timestep 154: Position (1, 9) ---
#
# --- Timestep 155: Position (1, 9) ---
#
# --- Timestep 156: Position (1, 9) ---
#
# --- Timestep 157: Position (1, 9) ---
#
# --- Timestep 158: Position (1, 9) ---
#
# --- Timestep 159: Position (1, 9) ---
#
# --- Timestep 160: Position (1, 9) ---
#
# --- Timestep 161: Position (1, 9) ---
#
# --- Timestep 162: Position (1, 9) ---
#
# --- Timestep 163: Position (1, 9) ---
#
# --- Timestep 164: Position (1, 9) ---
#
# --- Timestep 165: Position (1, 9) ---
#
# --- Timestep 166: Position (1, 9) ---
#
# --- Timestep 167: Position (1, 9) ---
#
# --- Timestep 168: Position (1, 9) ---
#
# --- Timestep 169: Position (1, 9) ---
#
# --- Timestep 170: Position (1, 9) ---
#
# --- Timestep 171: Position (1, 9) ---
#
# --- Timestep 172: Position (1, 9) ---
#
# --- Timestep 173: Position (1, 9) ---
#
# --- Timestep 174: Position (0, 9) ---
#
# --- Timestep 175: Position (0, 9) ---
#
# --- Timestep 176: Position (0, 9) ---
#
# --- Timestep 177: Position (0, 9) ---
#
# --- Timestep 178: Position (0, 9) ---
#
# --- Timestep 179: Position (0, 9) ---
#
# --- Timestep 180: Position (0, 9) ---
#
# --- Timestep 181: Position (0, 9) ---
#
# --- Timestep 182: Position (0, 9) ---
#
# --- Timestep 183: Position (0, 9) ---
#
# --- Timestep 184: Position (0, 9) ---
#
# --- Timestep 185: Position (0, 9) ---
#
# --- Timestep 186: Position (0, 9) ---
#
# --- Timestep 187: Position (0, 9) ---
#
# --- Timestep 188: Position (0, 9) ---
#
# --- Timestep 189: Position (0, 9) ---
#
# --- Timestep 190: Position (0, 9) ---
#
# --- Timestep 191: Position (0, 9) ---
#
# --- Timestep 192: Position (0, 9) ---
#
# --- Timestep 193: Position (0, 9) ---
#
# --- Timestep 194: Position (0, 9) ---
#
# --- Timestep 195: Position (0, 9) ---
#
# --- Timestep 196: Position (0, 9) ---
#
# --- Timestep 197: Position (0, 9) ---
#
# --- Timestep 198: Position (0, 9) ---
#
# --- Timestep 199: Position (0, 9) ---
#
# --- Timestep 200: Position (0, 9) ---
#
# --- Timestep 201: Position (0, 9) ---
#
# --- Timestep 202: Position (0, 9) ---
#
# --- Timestep 203: Position (0, 9) ---
#
# --- Timestep 204: Position (0, 9) ---
#
# --- Timestep 205: Position (0, 9) ---
#
# --- Timestep 206: Position (0, 9) ---
#
# --- Timestep 207: Position (0, 9) ---
#
# --- Timestep 208: Position (0, 9) ---
#
# --- Timestep 209: Position (0, 9) ---
#
# --- Timestep 210: Position (0, 9) ---
#
# --- Timestep 211: Position (0, 9) ---
#
# --- Timestep 212: Position (0, 9) ---
#
# --- Timestep 213: Position (0, 9) ---
#
# --- Timestep 214: Position (0, 9) ---
#
# --- Timestep 215: Position (0, 9) ---
#
# --- Timestep 216: Position (0, 9) ---
#
# --- Timestep 217: Position (0, 9) ---
#
# --- Timestep 218: Position (0, 9) ---
#
# --- Timestep 219: Position (0, 9) ---
#
# --- Timestep 220: Position (0, 9) ---
#
# --- Timestep 221: Position (0, 9) ---
#
# --- Timestep 222: Position (0, 9) ---
#
# --- Timestep 223: Position (0, 9) ---
#
# --- Timestep 224: Position (0, 9) ---
#
# --- Timestep 225: Position (0, 9) ---
#
# --- Timestep 226: Position (1, 9) ---
#
# --- Timestep 227: Position (1, 9) ---
#
# --- Timestep 228: Position (1, 9) ---
#
# --- Timestep 229: Position (1, 9) ---
#
# --- Timestep 230: Position (0, 9) ---
#
# --- Timestep 231: Position (0, 9) ---
#
# --- Timestep 232: Position (0, 9) ---
#
# --- Timestep 233: Position (0, 9) ---
#
# --- Timestep 234: Position (0, 9) ---
#
# --- Timestep 235: Position (0, 9) ---
#
# --- Timestep 236: Position (0, 9) ---
#
# --- Timestep 237: Position (0, 9) ---
#
# --- Timestep 238: Position (0, 9) ---
#
# --- Timestep 239: Position (0, 9) ---
#
# --- Timestep 240: Position (0, 9) ---
#
# --- Timestep 241: Position (0, 9) ---
#
# --- Timestep 242: Position (0, 9) ---
#
# --- Timestep 243: Position (0, 9) ---
#
# --- Timestep 244: Position (0, 9) ---
#
# --- Timestep 245: Position (0, 8) ---
#
# --- Timestep 246: Position (0, 8) ---
#
# --- Timestep 247: Position (0, 8) ---
#
# --- Timestep 248: Position (0, 8) ---
#
# --- Timestep 249: Position (0, 8) ---
#
# --- Timestep 250: Position (0, 8) ---
#
# --- Timestep 251: Position (0, 8) ---
#
# --- Timestep 252: Position (0, 8) ---
#
# --- Timestep 253: Position (0, 8) ---
#
# --- Timestep 254: Position (0, 8) ---
#
# --- Timestep 255: Position (0, 8) ---
#
# --- Timestep 256: Position (0, 8) ---
#
# --- Timestep 257: Position (0, 8) ---
#
# --- Timestep 258: Position (0, 8) ---
#
# --- Timestep 259: Position (0, 8) ---
#
# --- Timestep 260: Position (0, 8) ---
#
# --- Timestep 261: Position (0, 8) ---
#
# --- Timestep 262: Position (0, 8) ---
#
# --- Timestep 263: Position (0, 8) ---
#
# --- Timestep 264: Position (0, 8) ---
#
# --- Timestep 265: Position (0, 8) ---
#
# --- Timestep 266: Position (0, 8) ---
#
# --- Timestep 267: Position (0, 8) ---
#
# --- Timestep 268: Position (0, 7) ---
#
# --- Timestep 269: Position (0, 7) ---
#
# --- Timestep 270: Position (0, 7) ---
#
# --- Timestep 271: Position (0, 7) ---
#
# --- Timestep 272: Position (0, 7) ---
#
# --- Timestep 273: Position (0, 7) ---
#
# --- Timestep 274: Position (0, 7) ---
#
# --- Timestep 275: Position (0, 7) ---
#
# --- Timestep 276: Position (0, 7) ---
#
# --- Timestep 277: Position (0, 7) ---
#
# --- Timestep 278: Position (0, 7) ---
#
# --- Timestep 279: Position (0, 7) ---
#
# --- Timestep 280: Position (0, 7) ---
#
# --- Timestep 281: Position (0, 7) ---
#
# --- Timestep 282: Position (0, 7) ---
#
# --- Timestep 283: Position (0, 7) ---
#
# --- Timestep 284: Position (0, 7) ---
#
# --- Timestep 285: Position (0, 7) ---
#
# --- Timestep 286: Position (0, 7) ---
#
# --- Timestep 287: Position (0, 7) ---
#
# --- Timestep 288: Position (0, 7) ---
#
# --- Timestep 289: Position (0, 7) ---
#
# --- Timestep 290: Position (0, 7) ---
#
# --- Timestep 291: Position (0, 7) ---
#
# --- Timestep 292: Position (0, 7) ---
#
# --- Timestep 293: Position (0, 7) ---
#
# --- Timestep 294: Position (0, 7) ---
#
# --- Timestep 295: Position (0, 7) ---
#
# --- Timestep 296: Position (0, 7) ---
#
# --- Timestep 297: Position (0, 7) ---
#
# --- Timestep 298: Position (0, 7) ---
#
# --- Timestep 299: Position (0, 7) ---
#
# --- Timestep 300: Position (0, 7) ---
#
# --- Timestep 301: Position (0, 7) ---
#
# --- Timestep 302: Position (0, 7) ---
#
# --- Timestep 303: Position (0, 7) ---
#
# --- Timestep 304: Position (0, 7) ---
#
# --- Timestep 305: Position (0, 7) ---
#
# --- Timestep 306: Position (0, 7) ---
#
# --- Timestep 307: Position (0, 7) ---
#
# --- Timestep 308: Position (0, 7) ---
#
# --- Timestep 309: Position (0, 7) ---
#
# --- Timestep 310: Position (1, 7) ---
#
# --- Timestep 311: Position (1, 7) ---
#
# --- Timestep 312: Position (1, 7) ---
#
# --- Timestep 313: Position (1, 7) ---
#
# --- Timestep 314: Position (1, 7) ---
#
# --- Timestep 315: Position (1, 7) ---
#
# --- Timestep 316: Position (1, 7) ---
#
# --- Timestep 317: Position (1, 7) ---
#
# --- Timestep 318: Position (1, 7) ---
#
# --- Timestep 319: Position (1, 7) ---
#
# --- Timestep 320: Position (1, 7) ---
#
# --- Timestep 321: Position (1, 7) ---
#
# --- Timestep 322: Position (1, 7) ---
#
# --- Timestep 323: Position (1, 7) ---
#
# --- Timestep 324: Position (1, 7) ---
#
# --- Timestep 325: Position (1, 7) ---
#
# --- Timestep 326: Position (1, 7) ---
#
# --- Timestep 327: Position (1, 7) ---
#
# --- Timestep 328: Position (1, 7) ---
#
# --- Timestep 329: Position (1, 7) ---
#
# --- Timestep 330: Position (1, 7) ---
#
# --- Timestep 331: Position (1, 7) ---
#
# --- Timestep 332: Position (1, 7) ---
#
# --- Timestep 333: Position (1, 7) ---
#
# --- Timestep 334: Position (1, 7) ---
#
# --- Timestep 335: Position (1, 7) ---
#
# --- Timestep 336: Position (1, 7) ---
#
# --- Timestep 337: Position (1, 7) ---
#
# --- Timestep 338: Position (1, 7) ---
#
# --- Timestep 339: Position (1, 7) ---
#
# --- Timestep 340: Position (1, 7) ---
#
# --- Timestep 341: Position (1, 7) ---
#
# --- Timestep 342: Position (1, 7) ---
#
# --- Timestep 343: Position (1, 7) ---
#
# --- Timestep 344: Position (1, 7) ---
#
# --- Timestep 345: Position (1, 7) ---
#
# --- Timestep 346: Position (1, 7) ---
#
# --- Timestep 347: Position (1, 7) ---
#
# --- Timestep 348: Position (1, 7) ---
#
# --- Timestep 349: Position (1, 7) ---
#
# --- Timestep 350: Position (1, 7) ---
#
# --- Timestep 351: Position (1, 7) ---
#
# --- Timestep 352: Position (1, 7) ---
#
# --- Timestep 353: Position (1, 7) ---
#
# --- Timestep 354: Position (1, 7) ---
#
# --- Timestep 355: Position (1, 7) ---
#
# --- Timestep 356: Position (1, 7) ---
#
# --- Timestep 357: Position (1, 7) ---
#
# --- Timestep 358: Position (1, 7) ---
#
# --- Timestep 359: Position (1, 7) ---
#
# --- Timestep 360: Position (1, 7) ---
#
# --- Timestep 361: Position (1, 7) ---
#
# --- Timestep 362: Position (1, 7) ---
#
# --- Timestep 363: Position (2, 7) ---
#
# --- Timestep 364: Position (2, 7) ---
#
# --- Timestep 365: Position (2, 7) ---
#
# --- Timestep 366: Position (2, 7) ---
#
# --- Timestep 367: Position (2, 7) ---
#
# --- Timestep 368: Position (2, 7) ---
#
# --- Timestep 369: Position (2, 7) ---
#
# --- Timestep 370: Position (2, 7) ---
#
# --- Timestep 371: Position (2, 7) ---
#
# --- Timestep 372: Position (2, 7) ---
#
# --- Timestep 373: Position (2, 7) ---
#
# --- Timestep 374: Position (2, 7) ---
#
# --- Timestep 375: Position (2, 7) ---
#
# --- Timestep 376: Position (2, 7) ---
#
# --- Timestep 377: Position (2, 7) ---
#
# --- Timestep 378: Position (2, 7) ---
#
# --- Timestep 379: Position (2, 7) ---
#
# --- Timestep 380: Position (2, 7) ---
#
# --- Timestep 381: Position (2, 7) ---
#
# --- Timestep 382: Position (2, 7) ---
#
# --- Timestep 383: Position (2, 7) ---
#
# --- Timestep 384: Position (2, 7) ---
#
# --- Timestep 385: Position (2, 7) ---
#
# --- Timestep 386: Position (2, 7) ---
#
# --- Timestep 387: Position (2, 7) ---
#
# --- Timestep 388: Position (2, 7) ---
#
# --- Timestep 389: Position (2, 7) ---
#
# --- Timestep 390: Position (2, 7) ---
#
# --- Timestep 391: Position (2, 7) ---
#
# --- Timestep 392: Position (2, 7) ---
#
# --- Timestep 393: Position (2, 7) ---
#
# --- Timestep 394: Position (2, 7) ---
#
# --- Timestep 395: Position (2, 7) ---
#
# --- Timestep 396: Position (2, 7) ---
#
# --- Timestep 397: Position (2, 7) ---
#
# --- Timestep 398: Position (2, 7) ---
#
# --- Timestep 399: Position (3, 7) ---
#
# --- Timestep 400: Position (3, 7) ---
#
# --- Timestep 401: Position (3, 7) ---
#
# --- Timestep 402: Position (3, 7) ---
#
# --- Timestep 403: Position (3, 7) ---
#
# --- Timestep 404: Position (3, 7) ---
#
# --- Timestep 405: Position (3, 7) ---
#
# --- Timestep 406: Position (3, 7) ---
#
# --- Timestep 407: Position (3, 7) ---
#
# --- Timestep 408: Position (3, 7) ---
#
# --- Timestep 409: Position (3, 7) ---
#
# --- Timestep 410: Position (3, 7) ---
#
# --- Timestep 411: Position (3, 7) ---
#
# --- Timestep 412: Position (3, 7) ---
#
# --- Timestep 413: Position (3, 7) ---
#
# --- Timestep 414: Position (3, 7) ---
#
# --- Timestep 415: Position (3, 7) ---
#
# --- Timestep 416: Position (3, 7) ---
#
# --- Timestep 417: Position (3, 7) ---
#
# --- Timestep 418: Position (3, 7) ---
#
# --- Timestep 419: Position (3, 7) ---
#
# --- Timestep 420: Position (3, 7) ---
#
# --- Timestep 421: Position (3, 7) ---
#
# --- Timestep 422: Position (3, 7) ---
#
# --- Timestep 423: Position (3, 7) ---
#
# --- Timestep 424: Position (3, 7) ---
#
# --- Timestep 425: Position (3, 7) ---
#
# --- Timestep 426: Position (3, 7) ---
#
# --- Timestep 427: Position (3, 7) ---
#
# --- Timestep 428: Position (3, 7) ---
#
# --- Timestep 429: Position (3, 7) ---
#
# --- Timestep 430: Position (3, 7) ---
#
# --- Timestep 431: Position (3, 7) ---
#
# --- Timestep 432: Position (3, 7) ---
#
# --- Timestep 433: Position (3, 7) ---
#
# --- Timestep 434: Position (3, 7) ---
#
# --- Timestep 435: Position (3, 7) ---
#
# --- Timestep 436: Position (3, 7) ---
#
# --- Timestep 437: Position (3, 7) ---
#
# --- Timestep 438: Position (3, 7) ---
#
# --- Timestep 439: Position (2, 7) ---
#
# --- Timestep 440: Position (2, 7) ---
#
# --- Timestep 441: Position (2, 7) ---
#
# --- Timestep 442: Position (2, 7) ---
#
# --- Timestep 443: Position (2, 6) ---
#
# --- Timestep 444: Position (2, 6) ---
#
# --- Timestep 445: Position (2, 6) ---
#
# --- Timestep 446: Position (2, 6) ---
#
# --- Timestep 447: Position (2, 6) ---
#
# --- Timestep 448: Position (2, 6) ---
#
# --- Timestep 449: Position (2, 6) ---
#
# --- Timestep 450: Position (2, 6) ---
#
# --- Timestep 451: Position (2, 6) ---
#
# --- Timestep 452: Position (2, 6) ---
#
# --- Timestep 453: Position (2, 6) ---
#
# --- Timestep 454: Position (2, 6) ---
#
# --- Timestep 455: Position (2, 6) ---
#
# --- Timestep 456: Position (3, 6) ---
#
# --- Timestep 457: Position (2, 6) ---
#
# --- Timestep 458: Position (2, 6) ---
#
# --- Timestep 459: Position (3, 6) ---
#
# --- Timestep 460: Position (3, 6) ---
#
# --- Timestep 461: Position (2, 6) ---
#
# --- Timestep 462: Position (2, 6) ---
#
# --- Timestep 463: Position (2, 6) ---
#
# --- Timestep 464: Position (2, 6) ---
#
# --- Timestep 465: Position (2, 6) ---
#
# --- Timestep 466: Position (2, 6) ---
#
# --- Timestep 467: Position (2, 6) ---
#
# --- Timestep 468: Position (2, 6) ---
#
# --- Timestep 469: Position (2, 6) ---
#
# --- Timestep 470: Position (2, 6) ---
#
# --- Timestep 471: Position (2, 6) ---
#
# --- Timestep 472: Position (2, 6) ---
#
# --- Timestep 473: Position (2, 6) ---
#
# --- Timestep 474: Position (2, 6) ---
#
# --- Timestep 475: Position (2, 6) ---
#
# --- Timestep 476: Position (2, 6) ---
#
# --- Timestep 477: Position (2, 6) ---
#
# --- Timestep 478: Position (2, 6) ---
#
# --- Timestep 479: Position (2, 6) ---
#
# --- Timestep 480: Position (2, 6) ---
#
# --- Timestep 481: Position (2, 6) ---
#
# --- Timestep 482: Position (2, 6) ---
#
# --- Timestep 483: Position (2, 6) ---
#
# --- Timestep 484: Position (2, 6) ---
#
# --- Timestep 485: Position (2, 6) ---
#
# --- Timestep 486: Position (2, 6) ---
#
# --- Timestep 487: Position (2, 6) ---
#
# --- Timestep 488: Position (2, 6) ---
#
# --- Timestep 489: Position (2, 6) ---
#
# --- Timestep 490: Position (2, 6) ---
#
# --- Timestep 491: Position (2, 6) ---
#
# --- Timestep 492: Position (2, 6) ---
#
# --- Timestep 493: Position (2, 6) ---
#
# --- Timestep 494: Position (2, 6) ---
#
# --- Timestep 495: Position (2, 6) ---
#
# --- Timestep 496: Position (2, 7) ---
#
# --- Timestep 497: Position (2, 7) ---
#
# --- Timestep 498: Position (2, 7) ---
#
# --- Timestep 499: Position (2, 7) ---
#
# --- Timestep 500: Position (2, 7) ---
#
# --- Timestep 501: Position (2, 7) ---
#
# --- Timestep 502: Position (2, 7) ---
#
# --- Timestep 503: Position (2, 7) ---
#
# --- Timestep 504: Position (2, 7) ---
#
# --- Timestep 505: Position (2, 7) ---
#
# --- Timestep 506: Position (2, 7) ---
#
# --- Timestep 507: Position (2, 7) ---
#
# --- Timestep 508: Position (2, 7) ---
#
# --- Timestep 509: Position (2, 7) ---
#
# --- Timestep 510: Position (2, 7) ---
#
# --- Timestep 511: Position (2, 7) ---
#
# --- Timestep 512: Position (2, 7) ---
#
# --- Timestep 513: Position (2, 6) ---
#
# --- Timestep 514: Position (2, 6) ---
#
# --- Timestep 515: Position (2, 6) ---
#
# --- Timestep 516: Position (2, 6) ---
#
# --- Timestep 517: Position (2, 6) ---
#
# --- Timestep 518: Position (2, 6) ---
#
# --- Timestep 519: Position (2, 6) ---
#
# --- Timestep 520: Position (2, 6) ---
#
# --- Timestep 521: Position (2, 6) ---
#
# --- Timestep 522: Position (2, 6) ---
#
# --- Timestep 523: Position (2, 6) ---
#
# --- Timestep 524: Position (2, 6) ---
#
# --- Timestep 525: Position (2, 6) ---
#
# --- Timestep 526: Position (2, 6) ---
#
# --- Timestep 527: Position (2, 6) ---
#
# --- Timestep 528: Position (2, 6) ---
#
# --- Timestep 529: Position (2, 6) ---
#
# --- Timestep 530: Position (2, 6) ---
#
# --- Timestep 531: Position (2, 6) ---
#
# --- Timestep 532: Position (2, 6) ---
#
# --- Timestep 533: Position (2, 5) ---
#
# --- Timestep 534: Position (2, 5) ---
#
# --- Timestep 535: Position (2, 5) ---
#
# --- Timestep 536: Position (2, 5) ---
#
# --- Timestep 537: Position (2, 5) ---
#
# --- Timestep 538: Position (2, 5) ---
#
# --- Timestep 539: Position (2, 5) ---
#
# --- Timestep 540: Position (2, 5) ---
#
# --- Timestep 541: Position (2, 5) ---
#
# --- Timestep 542: Position (2, 5) ---
#
# --- Timestep 543: Position (2, 5) ---
#
# --- Timestep 544: Position (2, 5) ---
#
# --- Timestep 545: Position (2, 5) ---
#
# --- Timestep 546: Position (2, 5) ---
#
# --- Timestep 547: Position (2, 5) ---
#
# --- Timestep 548: Position (2, 5) ---
#
# --- Timestep 549: Position (2, 5) ---
#
# --- Timestep 550: Position (2, 5) ---
#
# --- Timestep 551: Position (2, 5) ---
#
# --- Timestep 552: Position (2, 5) ---
#
# --- Timestep 553: Position (2, 5) ---
#
# --- Timestep 554: Position (2, 5) ---
#
# --- Timestep 555: Position (2, 5) ---
#
# --- Timestep 556: Position (2, 5) ---
#
# --- Timestep 557: Position (2, 5) ---
#
# --- Timestep 558: Position (2, 5) ---
#
# --- Timestep 559: Position (2, 5) ---
#
# --- Timestep 560: Position (2, 5) ---
#
# --- Timestep 561: Position (2, 5) ---
#
# --- Timestep 562: Position (2, 5) ---
#
# --- Timestep 563: Position (2, 5) ---
#
# --- Timestep 564: Position (2, 5) ---
#
# --- Timestep 565: Position (2, 4) ---
#
# --- Timestep 566: Position (2, 4) ---
#
# --- Timestep 567: Position (2, 4) ---
#
# --- Timestep 568: Position (2, 4) ---
#
# --- Timestep 569: Position (2, 4) ---
#
# --- Timestep 570: Position (2, 4) ---
#
# --- Timestep 571: Position (2, 4) ---
#
# --- Timestep 572: Position (2, 4) ---
#
# --- Timestep 573: Position (2, 4) ---
#
# --- Timestep 574: Position (2, 4) ---
#
# --- Timestep 575: Position (2, 4) ---
#
# --- Timestep 576: Position (2, 4) ---
#
# --- Timestep 577: Position (2, 4) ---
#
# --- Timestep 578: Position (2, 4) ---
#
# --- Timestep 579: Position (2, 4) ---
#
# --- Timestep 580: Position (2, 4) ---
#
# --- Timestep 581: Position (2, 4) ---
#
# --- Timestep 582: Position (2, 4) ---
#
# --- Timestep 583: Position (2, 4) ---
#
# --- Timestep 584: Position (2, 4) ---
#
# --- Timestep 585: Position (2, 4) ---
#
# --- Timestep 586: Position (2, 4) ---
#
# --- Timestep 587: Position (2, 4) ---
#
# --- Timestep 588: Position (2, 4) ---
#
# --- Timestep 589: Position (2, 4) ---
#
# --- Timestep 590: Position (2, 4) ---
#
# --- Timestep 591: Position (2, 4) ---
#
# --- Timestep 592: Position (2, 4) ---
#
# --- Timestep 593: Position (2, 4) ---
#
# --- Timestep 594: Position (2, 4) ---
#
# --- Timestep 595: Position (2, 4) ---
#
# --- Timestep 596: Position (2, 4) ---
#
# --- Timestep 597: Position (2, 4) ---
#
# --- Timestep 598: Position (2, 4) ---
#
# --- Timestep 599: Position (2, 4) ---
#
# --- Timestep 600: Position (2, 4) ---
#
# --- Timestep 601: Position (2, 4) ---
#
# --- Timestep 602: Position (2, 4) ---
#
# --- Timestep 603: Position (2, 4) ---
#
# --- Timestep 604: Position (2, 4) ---
#
# --- Timestep 605: Position (2, 4) ---
#
# --- Timestep 606: Position (2, 4) ---
#
# --- Timestep 607: Position (2, 4) ---
#
# --- Timestep 608: Position (2, 4) ---
#
# --- Timestep 609: Position (2, 4) ---
#
# --- Timestep 610: Position (2, 4) ---
#
# --- Timestep 611: Position (2, 4) ---
#
# --- Timestep 612: Position (2, 4) ---
#
# --- Timestep 613: Position (2, 4) ---
#
# --- Timestep 614: Position (2, 4) ---
#
# --- Timestep 615: Position (2, 4) ---
#
# --- Timestep 616: Position (2, 4) ---
#
# --- Timestep 617: Position (2, 4) ---
#
# --- Timestep 618: Position (3, 4) ---
#
# --- Timestep 619: Position (3, 4) ---
#
# --- Timestep 620: Position (3, 4) ---
#
# --- Timestep 621: Position (3, 4) ---
#
# --- Timestep 622: Position (3, 4) ---
#
# --- Timestep 623: Position (3, 4) ---
#
# --- Timestep 624: Position (3, 3) ---
#
# --- Timestep 625: Position (3, 3) ---
#
# --- Timestep 626: Position (3, 3) ---
#
# --- Timestep 627: Position (3, 3) ---
#
# --- Timestep 628: Position (3, 3) ---
#
# --- Timestep 629: Position (3, 3) ---
#
# --- Timestep 630: Position (3, 3) ---
#
# --- Timestep 631: Position (3, 3) ---
#
# --- Timestep 632: Position (3, 3) ---
#
# --- Timestep 633: Position (3, 3) ---
#
# --- Timestep 634: Position (3, 3) ---
#
# --- Timestep 635: Position (3, 3) ---
#
# --- Timestep 636: Position (3, 3) ---
#
# --- Timestep 637: Position (3, 3) ---
#
# --- Timestep 638: Position (3, 3) ---
#
# --- Timestep 639: Position (3, 3) ---
#
# --- Timestep 640: Position (3, 3) ---
#
# --- Timestep 641: Position (3, 3) ---
#
# --- Timestep 642: Position (3, 3) ---
#
# --- Timestep 643: Position (3, 3) ---
#
# --- Timestep 644: Position (3, 3) ---
#
# --- Timestep 645: Position (3, 3) ---
#
# --- Timestep 646: Position (3, 3) ---
#
# --- Timestep 647: Position (3, 3) ---
#
# --- Timestep 648: Position (3, 3) ---
#
# --- Timestep 649: Position (3, 3) ---
#
# --- Timestep 650: Position (3, 3) ---
#
# --- Timestep 651: Position (4, 3) ---
#
# --- Timestep 652: Position (4, 3) ---
#
# --- Timestep 653: Position (4, 3) ---
#
# --- Timestep 654: Position (4, 3) ---
#
# --- Timestep 655: Position (4, 3) ---
#
# --- Timestep 656: Position (4, 3) ---
#
# --- Timestep 657: Position (4, 3) ---
#
# --- Timestep 658: Position (4, 3) ---
#
# --- Timestep 659: Position (4, 3) ---
#
# --- Timestep 660: Position (4, 3) ---
#
# --- Timestep 661: Position (4, 3) ---
#
# --- Timestep 662: Position (4, 3) ---
#
# --- Timestep 663: Position (4, 3) ---
#
# --- Timestep 664: Position (4, 3) ---
#
# --- Timestep 665: Position (4, 3) ---
#
# --- Timestep 666: Position (4, 3) ---
#
# --- Timestep 667: Position (4, 3) ---
#
# --- Timestep 668: Position (4, 3) ---
#
# --- Timestep 669: Position (4, 3) ---
#
# --- Timestep 670: Position (4, 3) ---
#
# --- Timestep 671: Position (4, 3) ---
#
# --- Timestep 672: Position (4, 3) ---
#
# --- Timestep 673: Position (4, 3) ---
#
# --- Timestep 674: Position (4, 3) ---
#
# --- Timestep 675: Position (4, 3) ---
#
# --- Timestep 676: Position (4, 3) ---
#
# --- Timestep 677: Position (4, 3) ---
#
# --- Timestep 678: Position (4, 3) ---
#
# --- Timestep 679: Position (4, 3) ---
#
# --- Timestep 680: Position (4, 3) ---
#
# --- Timestep 681: Position (4, 3) ---
#
# --- Timestep 682: Position (4, 3) ---
#
# --- Timestep 683: Position (4, 3) ---
#
# --- Timestep 684: Position (4, 3) ---
#
# --- Timestep 685: Position (4, 4) ---
#
# --- Timestep 686: Position (4, 4) ---
#
# --- Timestep 687: Position (4, 4) ---
#
# --- Timestep 688: Position (4, 4) ---
#
# --- Timestep 689: Position (4, 4) ---
#
# --- Timestep 690: Position (4, 4) ---
#
# --- Timestep 691: Position (4, 4) ---
#
# --- Timestep 692: Position (4, 4) ---
#
# --- Timestep 693: Position (4, 4) ---
#
# --- Timestep 694: Position (4, 4) ---
#
# --- Timestep 695: Position (4, 4) ---
#
# --- Timestep 696: Position (4, 4) ---
#
# --- Timestep 697: Position (4, 4) ---
#
# --- Timestep 698: Position (4, 3) ---
#
# --- Timestep 699: Position (4, 3) ---
#
# --- Timestep 700: Position (4, 3) ---
#
# --- Timestep 701: Position (4, 3) ---
#
# --- Timestep 702: Position (4, 3) ---
#
# --- Timestep 703: Position (4, 3) ---
#
# --- Timestep 704: Position (4, 3) ---
#
# --- Timestep 705: Position (4, 3) ---
#
# --- Timestep 706: Position (4, 3) ---
#
# --- Timestep 707: Position (4, 3) ---
#
# --- Timestep 708: Position (4, 3) ---
#
# --- Timestep 709: Position (4, 3) ---
#
# --- Timestep 710: Position (4, 3) ---
#
# --- Timestep 711: Position (4, 3) ---
#
# --- Timestep 712: Position (4, 3) ---
#
# --- Timestep 713: Position (4, 3) ---
#
# --- Timestep 714: Position (4, 3) ---
#
# --- Timestep 715: Position (4, 3) ---
#
# --- Timestep 716: Position (4, 3) ---
#
# --- Timestep 717: Position (4, 3) ---
#
# --- Timestep 718: Position (5, 3) ---
#
# --- Timestep 719: Position (5, 3) ---
#
# --- Timestep 720: Position (5, 3) ---
#
# --- Timestep 721: Position (5, 3) ---
#
# --- Timestep 722: Position (5, 3) ---
#
# --- Timestep 723: Position (5, 3) ---
#
# --- Timestep 724: Position (5, 3) ---
#
# --- Timestep 725: Position (5, 3) ---
#
# --- Timestep 726: Position (5, 3) ---
#
# --- Timestep 727: Position (5, 3) ---
#
# --- Timestep 728: Position (5, 3) ---
#
# --- Timestep 729: Position (5, 3) ---
#
# --- Timestep 730: Position (5, 3) ---
#
# --- Timestep 731: Position (5, 3) ---
#
# --- Timestep 732: Position (5, 3) ---
#
# --- Timestep 733: Position (5, 3) ---
#
# --- Timestep 734: Position (5, 3) ---
#
# --- Timestep 735: Position (5, 3) ---
#
# --- Timestep 736: Position (5, 3) ---
#
# --- Timestep 737: Position (5, 3) ---
#
# --- Timestep 738: Position (5, 3) ---
#
# --- Timestep 739: Position (5, 3) ---
#
# --- Timestep 740: Position (5, 3) ---
#
# --- Timestep 741: Position (5, 3) ---
#
# --- Timestep 742: Position (5, 3) ---
#
# --- Timestep 743: Position (5, 3) ---
#
# --- Timestep 744: Position (5, 3) ---
#
# --- Timestep 745: Position (5, 3) ---
#
# --- Timestep 746: Position (5, 3) ---
#
# --- Timestep 747: Position (6, 3) ---
#
# --- Timestep 748: Position (6, 3) ---
#
# --- Timestep 749: Position (6, 3) ---
#
# --- Timestep 750: Position (6, 3) ---
#
# --- Timestep 751: Position (6, 3) ---
#
# --- Timestep 752: Position (6, 3) ---
#
# --- Timestep 753: Position (6, 3) ---
#
# --- Timestep 754: Position (6, 3) ---
#
# --- Timestep 755: Position (6, 3) ---
#
# --- Timestep 756: Position (6, 3) ---
#
# --- Timestep 757: Position (6, 3) ---
#
# --- Timestep 758: Position (6, 3) ---
#
# --- Timestep 759: Position (6, 3) ---
#
# --- Timestep 760: Position (6, 3) ---
#
# --- Timestep 761: Position (6, 3) ---
#
# --- Timestep 762: Position (6, 3) ---
#
# --- Timestep 763: Position (6, 3) ---
#
# --- Timestep 764: Position (6, 3) ---
#
# --- Timestep 765: Position (6, 3) ---
#
# --- Timestep 766: Position (6, 3) ---
#
# --- Timestep 767: Position (6, 3) ---
#
# --- Timestep 768: Position (6, 2) ---
#
# --- Timestep 769: Position (6, 2) ---
#
# --- Timestep 770: Position (6, 2) ---
#
# --- Timestep 771: Position (6, 2) ---
#
# --- Timestep 772: Position (6, 2) ---
#
# --- Timestep 773: Position (6, 2) ---
#
# --- Timestep 774: Position (6, 2) ---
#
# --- Timestep 775: Position (6, 2) ---
#
# --- Timestep 776: Position (6, 2) ---
#
# --- Timestep 777: Position (6, 2) ---
#
# --- Timestep 778: Position (6, 2) ---
#
# --- Timestep 779: Position (6, 2) ---
#
# --- Timestep 780: Position (6, 2) ---
#
# --- Timestep 781: Position (6, 2) ---
#
# --- Timestep 782: Position (6, 2) ---
#
# --- Timestep 783: Position (6, 2) ---
#
# --- Timestep 784: Position (6, 2) ---
#
# --- Timestep 785: Position (6, 2) ---
#
# --- Timestep 786: Position (6, 2) ---
#
# --- Timestep 787: Position (6, 2) ---
#
# --- Timestep 788: Position (6, 2) ---
#
# --- Timestep 789: Position (6, 2) ---
#
# --- Timestep 790: Position (7, 2) ---
#
# --- Timestep 791: Position (7, 2) ---
#
# --- Timestep 792: Position (7, 2) ---
#
# --- Timestep 793: Position (7, 2) ---
#
# --- Timestep 794: Position (7, 2) ---
#
# --- Timestep 795: Position (7, 2) ---
#
# --- Timestep 796: Position (7, 2) ---
#
# --- Timestep 797: Position (7, 2) ---
#
# --- Timestep 798: Position (7, 1) ---
#
# --- Timestep 799: Position (7, 1) ---
#
# --- Timestep 800: Position (7, 1) ---
#
# --- Timestep 801: Position (7, 1) ---
#
# --- Timestep 802: Position (7, 1) ---
#
# --- Timestep 803: Position (7, 1) ---
#
# --- Timestep 804: Position (7, 1) ---
#
# --- Timestep 805: Position (7, 1) ---
#
# --- Timestep 806: Position (7, 1) ---
#
# --- Timestep 807: Position (8, 1) ---
#
# --- Timestep 808: Position (8, 1) ---
#
# --- Timestep 809: Position (8, 1) ---
#
# --- Timestep 810: Position (8, 1) ---
#
# --- Timestep 811: Position (8, 1) ---
#
# --- Timestep 812: Position (8, 1) ---
#
# --- Timestep 813: Position (8, 1) ---
#
# --- Timestep 814: Position (8, 1) ---
#
# --- Timestep 815: Position (8, 1) ---
#
# --- Timestep 816: Position (8, 1) ---
#
# --- Timestep 817: Position (8, 1) ---
#
# --- Timestep 818: Position (8, 1) ---
#
# --- Timestep 819: Position (8, 1) ---
#
# --- Timestep 820: Position (8, 1) ---
#
# --- Timestep 821: Position (8, 1) ---
#
# --- Timestep 822: Position (8, 1) ---
#
# --- Timestep 823: Position (8, 1) ---
#
# --- Timestep 824: Position (8, 1) ---
#
# --- Timestep 825: Position (8, 1) ---
#
# --- Timestep 826: Position (8, 1) ---
#
# --- Timestep 827: Position (8, 1) ---
#
# --- Timestep 828: Position (8, 1) ---
#
# --- Timestep 829: Position (8, 1) ---
#
# --- Timestep 830: Position (9, 1) ---
#
# --- Timestep 831: Position (9, 0) ---
#
# --- Timestep 832: Position (9, 0) ---
#
# --- Timestep 833: Position (9, 0) ---
#
# --- Timestep 834: Position (9, 0) ---
#
# --- Timestep 835: Position (9, 0) ---
#
# --- Timestep 836: Position (9, 0) ---
#
# --- Timestep 837: Position (9, 0) ---
#
# --- Timestep 838: Position (9, 0) ---
#
# --- Timestep 839: Position (9, 0) ---
#
# --- Timestep 840: Position (9, 0) ---
#
# --- Timestep 841: Position (9, 0) ---
#
# --- Timestep 842: Position (9, 0) ---
#
# --- Timestep 843: Position (9, 0) ---
#
# --- Timestep 844: Position (9, 0) ---
#
# --- Timestep 845: Position (9, 0) ---
#
# --- Timestep 846: Position (9, 0) ---
#
# --- Timestep 847: Position (9, 0) ---
#
# --- Timestep 848: Position (9, 0) ---
#
# --- Timestep 849: Position (9, 0) ---
#
# --- Timestep 850: Position (9, 0) ---
#
# --- Timestep 851: Position (9, 0) ---
#
# --- Timestep 852: Position (9, 0) ---
#
# --- Timestep 853: Position (9, 0) ---
#
# --- Timestep 854: Position (9, 0) ---
#
# --- Timestep 855: Position (9, 0) ---
#
# --- Timestep 856: Position (9, 0) ---
#
# --- Timestep 857: Position (9, 0) ---
#
# --- Timestep 858: Position (9, 0) ---
#
# --- Timestep 859: Position (9, 0) ---
#
# --- Timestep 860: Position (9, 0) ---
#
# --- Timestep 861: Position (9, 0) ---
#
# --- Timestep 862: Position (9, 0) ---
#
# --- Timestep 863: Position (9, 0) ---
#
# --- Timestep 864: Position (9, 0) ---
#
# --- Timestep 865: Position (9, 0) ---
#
# --- Timestep 866: Position (9, 0) ---
#
# --- Timestep 867: Position (9, 0) ---
#
# --- Timestep 868: Position (9, 0) ---
#
# --- Timestep 869: Position (9, 0) ---
#
# --- Timestep 870: Position (9, 0) ---
#
# --- Timestep 871: Position (9, 0) ---
#
# --- Timestep 872: Position (9, 0) ---
#
# --- Timestep 873: Position (9, 0) ---
#
# --- Timestep 874: Position (9, 0) ---
#
# --- Timestep 875: Position (9, 0) ---
#
# --- Timestep 876: Position (9, 0) ---
#
# --- Timestep 877: Position (9, 0) ---
#
# --- Timestep 878: Position (9, 0) ---
#
# --- Timestep 879: Position (9, 0) ---
#
# --- Timestep 880: Position (8, 0) ---
#
# --- Timestep 881: Position (8, 0) ---
#
# --- Timestep 882: Position (8, 0) ---
#
# --- Timestep 883: Position (8, 0) ---
#
# --- Timestep 884: Position (8, 0) ---
#
# --- Timestep 885: Position (8, 0) ---
#
# --- Timestep 886: Position (8, 0) ---
#
# --- Timestep 887: Position (8, 0) ---
#
# --- Timestep 888: Position (8, 0) ---
#
# --- Timestep 889: Position (8, 0) ---
#
# --- Timestep 890: Position (8, 0) ---
#
# --- Timestep 891: Position (8, 0) ---
#
# --- Timestep 892: Position (8, 0) ---
#
# --- Timestep 893: Position (8, 0) ---
#
# --- Timestep 894: Position (8, 0) ---
#
# --- Timestep 895: Position (8, 0) ---
#
# --- Timestep 896: Position (8, 0) ---
#
# --- Timestep 897: Position (8, 0) ---
#
# --- Timestep 898: Position (8, 0) ---
#
# --- Timestep 899: Position (8, 0) ---
#
# --- Timestep 900: Position (8, 0) ---
#
# --- Timestep 901: Position (8, 0) ---
#
# --- Timestep 902: Position (8, 0) ---
#
# --- Timestep 903: Position (8, 0) ---
#
# --- Timestep 904: Position (8, 0) ---
#
# --- Timestep 905: Position (8, 0) ---
#
# --- Timestep 906: Position (8, 0) ---
#
# --- Timestep 907: Position (8, 0) ---
#
# --- Timestep 908: Position (8, 0) ---
#
# --- Timestep 909: Position (8, 0) ---
#
# --- Timestep 910: Position (8, 0) ---
#
# --- Timestep 911: Position (8, 0) ---
#
# --- Timestep 912: Position (8, 0) ---
#
# --- Timestep 913: Position (8, 0) ---
#
# --- Timestep 914: Position (8, 0) ---
#
# --- Timestep 915: Position (8, 0) ---
#
# --- Timestep 916: Position (8, 0) ---
#
# --- Timestep 917: Position (8, 0) ---
#
# --- Timestep 918: Position (8, 0) ---
#
# --- Timestep 919: Position (8, 0) ---
#
# --- Timestep 920: Position (8, 0) ---
#
# --- Timestep 921: Position (8, 0) ---
#
# --- Timestep 922: Position (8, 0) ---
#
# --- Timestep 923: Position (8, 0) ---
#
# --- Timestep 924: Position (8, 0) ---
#
# --- Timestep 925: Position (8, 0) ---
#
# --- Timestep 926: Position (7, 0) ---
#
# --- Timestep 927: Position (7, 0) ---
#
# --- Timestep 928: Position (7, 0) ---
#
# --- Timestep 929: Position (7, 0) ---
#
# --- Timestep 930: Position (7, 0) ---
#
# --- Timestep 931: Position (7, 0) ---
#
# --- Timestep 932: Position (7, 0) ---
#
# --- Timestep 933: Position (7, 0) ---
#
# --- Timestep 934: Position (7, 0) ---
#
# --- Timestep 935: Position (7, 0) ---
#
# --- Timestep 936: Position (7, 0) ---
#
# --- Timestep 937: Position (7, 0) ---
#
# --- Timestep 938: Position (7, 0) ---
#
# --- Timestep 939: Position (7, 0) ---
#
# --- Timestep 940: Position (7, 0) ---
#
# --- Timestep 941: Position (7, 0) ---
#
# --- Timestep 942: Position (7, 0) ---
#
# --- Timestep 943: Position (7, 0) ---
#
# --- Timestep 944: Position (7, 0) ---
#
# --- Timestep 945: Position (7, 0) ---
#
# --- Timestep 946: Position (7, 0) ---
#
# --- Timestep 947: Position (7, 0) ---
#
# --- Timestep 948: Position (7, 0) ---
#
# --- Timestep 949: Position (7, 0) ---
#
# --- Timestep 950: Position (7, 0) ---
#
# --- Timestep 951: Position (7, 0) ---
#
# --- Timestep 952: Position (7, 0) ---
#
# --- Timestep 953: Position (7, 0) ---
#
# --- Timestep 954: Position (6, 0) ---
#
# --- Timestep 955: Position (6, 0) ---
#
# --- Timestep 956: Position (6, 0) ---
#
# --- Timestep 957: Position (6, 0) ---
#
# --- Timestep 958: Position (6, 0) ---
#
# --- Timestep 959: Position (6, 0) ---
#
# --- Timestep 960: Position (6, 0) ---
#
# --- Timestep 961: Position (6, 0) ---
#
# --- Timestep 962: Position (6, 0) ---
#
# --- Timestep 963: Position (6, 0) ---
#
# --- Timestep 964: Position (6, 0) ---
#
# --- Timestep 965: Position (6, 0) ---
#
# --- Timestep 966: Position (6, 0) ---
#
# --- Timestep 967: Position (6, 0) ---
#
# --- Timestep 968: Position (6, 0) ---
#
# --- Timestep 969: Position (6, 0) ---
#
# --- Timestep 970: Position (6, 0) ---
#
# --- Timestep 971: Position (6, 0) ---
#
# --- Timestep 972: Position (6, 0) ---
#
# --- Timestep 973: Position (6, 0) ---
#
# --- Timestep 974: Position (6, 0) ---
#
# --- Timestep 975: Position (6, 0) ---
#
# --- Timestep 976: Position (6, 0) ---
#
# --- Timestep 977: Position (6, 0) ---
#
# --- Timestep 978: Position (6, 0) ---
#
# --- Timestep 979: Position (6, 0) ---
#
# --- Timestep 980: Position (6, 0) ---
#
# --- Timestep 981: Position (6, 0) ---
#
# --- Timestep 982: Position (6, 0) ---
#
# --- Timestep 983: Position (6, 0) ---
#
# --- Timestep 984: Position (6, 0) ---
#
# --- Timestep 985: Position (6, 0) ---
#
# --- Timestep 986: Position (6, 0) ---
#
# --- Timestep 987: Position (6, 0) ---
#
# --- Timestep 988: Position (6, 0) ---
#
# --- Timestep 989: Position (5, 0) ---
#
# --- Timestep 990: Position (5, 0) ---
#
# --- Timestep 991: Position (5, 0) ---
#
# --- Timestep 992: Position (5, 0) ---
#
# --- Timestep 993: Position (5, 0) ---
#
# --- Timestep 994: Position (5, 0) ---
#
# --- Timestep 995: Position (5, 0) ---
#
# --- Timestep 996: Position (5, 0) ---
#
# --- Timestep 997: Position (5, 0) ---
#
# --- Timestep 998: Position (5, 0) ---
#
# --- Timestep 999: Position (5, 0) ---
#
# --- Timestep 1000: Position (5, 0) ---

# %% [markdown]
# plot_sensory_input_subplots(sensoryInputGrids, PC_idx, nCols=6)

# %%
# Reset initial NetAct to a random state (you can customize this if needed)
NetAct = np.random.rand(rows, cols) * 0.5
NetAct = NetAct / np.max(NetAct)  # Normalize

# %%
results = np.zeros((len(sensoryInputGrids), rows, cols))


for i, (sensoryInputGridNormalised, pcRow, pcCol, timestep) in enumerate(sensoryInputGrids):
    print(f"\n--- Running network update for timestep {timestep} ---")

    # Option 1: Blend sensory input into current NetAct
    NetAct = blend_factor * sensoryInputGridNormalised + (1 - blend_factor) * NetAct

    for _ in range(nIterationsPerTimestep):
        NetInput = np.zeros((rows, cols))

        for k in range(nCells):
            row, col = np.where(PC_idx == k)
            NetInput += weightsMat[:, :, k] * NetAct[row, col]

        # Option 2: Add sensory input again during recurrent loop
        NetInput += sensoryInputGridNormalised

        NetInput = NetInput - np.min(NetInput)
        if np.max(NetInput) > 0:
            NetInput = NetInput / np.max(NetInput)
        NetInput = NetInput * (NetInput >= NetThreshold)

        NetAct = NetInput.copy()

    results[i, :, :] = NetAct
    peak = np.unravel_index(np.argmax(NetAct), NetAct.shape)
    print(f"Timestep {timestep} bump peak: {peak}")

# create3Dplot(results, trajectory_positions, PC_idx, sensoryInputGrids)
# Out:
# --- Running network update for timestep 1 ---
# Timestep 1 bump peak: (2, 7)
#
# --- Running network update for timestep 2 ---
# Timestep 2 bump peak: (2, 7)
#
# --- Running network update for timestep 3 ---
# Timestep 3 bump peak: (2, 7)
#
# --- Running network update for timestep 4 ---
# Timestep 4 bump peak: (2, 7)
#
# --- Running network update for timestep 5 ---
# Timestep 5 bump peak: (2, 7)
#
# --- Running network update for timestep 6 ---
# Timestep 6 bump peak: (2, 7)
#
# --- Running network update for timestep 7 ---
# Timestep 7 bump peak: (2, 7)
#
# --- Running network update for timestep 8 ---
# Timestep 8 bump peak: (2, 7)
#
# --- Running network update for timestep 9 ---
# Timestep 9 bump peak: (2, 7)
#
# --- Running network update for timestep 10 ---
# Timestep 10 bump peak: (2, 7)
#
# --- Running network update for timestep 11 ---
# Timestep 11 bump peak: (2, 7)
#
# --- Running network update for timestep 12 ---
# Timestep 12 bump peak: (2, 7)
#
# --- Running network update for timestep 13 ---
# Timestep 13 bump peak: (2, 7)
#
# --- Running network update for timestep 14 ---
# Timestep 14 bump peak: (1, 7)
#
# --- Running network update for timestep 15 ---
# Timestep 15 bump peak: (1, 7)
#
# --- Running network update for timestep 16 ---
# Timestep 16 bump peak: (1, 7)
#
# --- Running network update for timestep 17 ---
# Timestep 17 bump peak: (1, 7)
#
# --- Running network update for timestep 18 ---
# Timestep 18 bump peak: (1, 7)
#
# --- Running network update for timestep 19 ---
# Timestep 19 bump peak: (1, 7)
#
# --- Running network update for timestep 20 ---
# Timestep 20 bump peak: (1, 7)
#
# --- Running network update for timestep 21 ---
# Timestep 21 bump peak: (1, 7)
#
# --- Running network update for timestep 22 ---
# Timestep 22 bump peak: (1, 7)
#
# --- Running network update for timestep 23 ---
# Timestep 23 bump peak: (1, 7)
#
# --- Running network update for timestep 24 ---
# Timestep 24 bump peak: (1, 7)
#
# --- Running network update for timestep 25 ---
# Timestep 25 bump peak: (1, 7)
#
# --- Running network update for timestep 26 ---
# Timestep 26 bump peak: (1, 7)
#
# --- Running network update for timestep 27 ---
# Timestep 27 bump peak: (1, 7)
#
# --- Running network update for timestep 28 ---
# Timestep 28 bump peak: (1, 6)
#
# --- Running network update for timestep 29 ---
# Timestep 29 bump peak: (1, 6)
#
# --- Running network update for timestep 30 ---
# Timestep 30 bump peak: (1, 6)
#
# --- Running network update for timestep 31 ---
# Timestep 31 bump peak: (1, 6)
#
# --- Running network update for timestep 32 ---
# Timestep 32 bump peak: (1, 6)
#
# --- Running network update for timestep 33 ---
# Timestep 33 bump peak: (1, 6)
#
# --- Running network update for timestep 34 ---
# Timestep 34 bump peak: (1, 6)
#
# --- Running network update for timestep 35 ---
# Timestep 35 bump peak: (1, 7)
#
# --- Running network update for timestep 36 ---
# Timestep 36 bump peak: (1, 7)
#
# --- Running network update for timestep 37 ---
# Timestep 37 bump peak: (1, 7)
#
# --- Running network update for timestep 38 ---
# Timestep 38 bump peak: (1, 7)
#
# --- Running network update for timestep 39 ---
# Timestep 39 bump peak: (1, 7)
#
# --- Running network update for timestep 40 ---
# Timestep 40 bump peak: (1, 7)
#
# --- Running network update for timestep 41 ---
# Timestep 41 bump peak: (1, 7)
#
# --- Running network update for timestep 42 ---
# Timestep 42 bump peak: (1, 7)
#
# --- Running network update for timestep 43 ---
# Timestep 43 bump peak: (1, 7)
#
# --- Running network update for timestep 44 ---
# Timestep 44 bump peak: (1, 7)
#
# --- Running network update for timestep 45 ---
# Timestep 45 bump peak: (1, 7)
#
# --- Running network update for timestep 46 ---
# Timestep 46 bump peak: (1, 7)
#
# --- Running network update for timestep 47 ---
# Timestep 47 bump peak: (1, 7)
#
# --- Running network update for timestep 48 ---
# Timestep 48 bump peak: (1, 7)
#
# --- Running network update for timestep 49 ---
# Timestep 49 bump peak: (1, 7)
#
# --- Running network update for timestep 50 ---
# Timestep 50 bump peak: (1, 7)
#
# --- Running network update for timestep 51 ---
# Timestep 51 bump peak: (1, 7)
#
# --- Running network update for timestep 52 ---
# Timestep 52 bump peak: (1, 7)
#
# --- Running network update for timestep 53 ---
# Timestep 53 bump peak: (1, 7)
#
# --- Running network update for timestep 54 ---
# Timestep 54 bump peak: (1, 7)
#
# --- Running network update for timestep 55 ---
# Timestep 55 bump peak: (1, 7)
#
# --- Running network update for timestep 56 ---
# Timestep 56 bump peak: (1, 7)
#
# --- Running network update for timestep 57 ---
# Timestep 57 bump peak: (1, 7)
#
# --- Running network update for timestep 58 ---
# Timestep 58 bump peak: (1, 7)
#
# --- Running network update for timestep 59 ---
# Timestep 59 bump peak: (1, 7)
#
# --- Running network update for timestep 60 ---
# Timestep 60 bump peak: (1, 7)
#
# --- Running network update for timestep 61 ---
# Timestep 61 bump peak: (1, 7)
#
# --- Running network update for timestep 62 ---
# Timestep 62 bump peak: (1, 7)
#
# --- Running network update for timestep 63 ---
# Timestep 63 bump peak: (1, 7)
#
# --- Running network update for timestep 64 ---
# Timestep 64 bump peak: (1, 7)
#
# --- Running network update for timestep 65 ---
# Timestep 65 bump peak: (1, 7)
#
# --- Running network update for timestep 66 ---
# Timestep 66 bump peak: (1, 7)
#
# --- Running network update for timestep 67 ---
# Timestep 67 bump peak: (1, 7)
#
# --- Running network update for timestep 68 ---
# Timestep 68 bump peak: (1, 7)
#
# --- Running network update for timestep 69 ---
# Timestep 69 bump peak: (1, 7)
#
# --- Running network update for timestep 70 ---
# Timestep 70 bump peak: (1, 7)
#
# --- Running network update for timestep 71 ---
# Timestep 71 bump peak: (1, 7)
#
# --- Running network update for timestep 72 ---
# Timestep 72 bump peak: (1, 7)
#
# --- Running network update for timestep 73 ---
# Timestep 73 bump peak: (1, 7)
#
# --- Running network update for timestep 74 ---
# Timestep 74 bump peak: (1, 7)
#
# --- Running network update for timestep 75 ---
# Timestep 75 bump peak: (1, 7)
#
# --- Running network update for timestep 76 ---
# Timestep 76 bump peak: (1, 7)
#
# --- Running network update for timestep 77 ---
# Timestep 77 bump peak: (1, 7)
#
# --- Running network update for timestep 78 ---
# Timestep 78 bump peak: (1, 7)
#
# --- Running network update for timestep 79 ---
# Timestep 79 bump peak: (1, 7)
#
# --- Running network update for timestep 80 ---
# Timestep 80 bump peak: (1, 7)
#
# --- Running network update for timestep 81 ---
# Timestep 81 bump peak: (1, 7)
#
# --- Running network update for timestep 82 ---
# Timestep 82 bump peak: (1, 7)
#
# --- Running network update for timestep 83 ---
# Timestep 83 bump peak: (1, 7)
#
# --- Running network update for timestep 84 ---
# Timestep 84 bump peak: (1, 7)
#
# --- Running network update for timestep 85 ---
# Timestep 85 bump peak: (1, 7)
#
# --- Running network update for timestep 86 ---
# Timestep 86 bump peak: (1, 7)
#
# --- Running network update for timestep 87 ---
# Timestep 87 bump peak: (1, 7)
#
# --- Running network update for timestep 88 ---
# Timestep 88 bump peak: (1, 7)
#
# --- Running network update for timestep 89 ---
# Timestep 89 bump peak: (1, 7)
#
# --- Running network update for timestep 90 ---
# Timestep 90 bump peak: (1, 7)
#
# --- Running network update for timestep 91 ---
# Timestep 91 bump peak: (1, 7)
#
# --- Running network update for timestep 92 ---
# Timestep 92 bump peak: (1, 7)
#
# --- Running network update for timestep 93 ---
# Timestep 93 bump peak: (1, 7)
#
# --- Running network update for timestep 94 ---
# Timestep 94 bump peak: (1, 7)
#
# --- Running network update for timestep 95 ---
# Timestep 95 bump peak: (1, 7)
#
# --- Running network update for timestep 96 ---
# Timestep 96 bump peak: (1, 7)
#
# --- Running network update for timestep 97 ---
# Timestep 97 bump peak: (1, 7)
#
# --- Running network update for timestep 98 ---
# Timestep 98 bump peak: (1, 7)
#
# --- Running network update for timestep 99 ---
# Timestep 99 bump peak: (1, 7)
#
# --- Running network update for timestep 100 ---
# Timestep 100 bump peak: (1, 7)
#
# --- Running network update for timestep 101 ---
# Timestep 101 bump peak: (1, 7)
#
# --- Running network update for timestep 102 ---
# Timestep 102 bump peak: (1, 7)
#
# --- Running network update for timestep 103 ---
# Timestep 103 bump peak: (1, 7)
#
# --- Running network update for timestep 104 ---
# Timestep 104 bump peak: (1, 7)
#
# --- Running network update for timestep 105 ---
# Timestep 105 bump peak: (1, 7)
#
# --- Running network update for timestep 106 ---
# Timestep 106 bump peak: (1, 7)
#
# --- Running network update for timestep 107 ---
# Timestep 107 bump peak: (1, 7)
#
# --- Running network update for timestep 108 ---
# Timestep 108 bump peak: (1, 7)
#
# --- Running network update for timestep 109 ---
# Timestep 109 bump peak: (1, 7)
#
# --- Running network update for timestep 110 ---
# Timestep 110 bump peak: (1, 7)
#
# --- Running network update for timestep 111 ---
# Timestep 111 bump peak: (1, 7)
#
# --- Running network update for timestep 112 ---
# Timestep 112 bump peak: (1, 7)
#
# --- Running network update for timestep 113 ---
# Timestep 113 bump peak: (1, 7)
#
# --- Running network update for timestep 114 ---
# Timestep 114 bump peak: (1, 7)
#
# --- Running network update for timestep 115 ---
# Timestep 115 bump peak: (1, 7)
#
# --- Running network update for timestep 116 ---
# Timestep 116 bump peak: (1, 7)
#
# --- Running network update for timestep 117 ---
# Timestep 117 bump peak: (1, 7)
#
# --- Running network update for timestep 118 ---
# Timestep 118 bump peak: (1, 7)
#
# --- Running network update for timestep 119 ---
# Timestep 119 bump peak: (1, 7)
#
# --- Running network update for timestep 120 ---
# Timestep 120 bump peak: (1, 7)
#
# --- Running network update for timestep 121 ---
# Timestep 121 bump peak: (1, 7)
#
# --- Running network update for timestep 122 ---
# Timestep 122 bump peak: (1, 7)
#
# --- Running network update for timestep 123 ---
# Timestep 123 bump peak: (1, 7)
#
# --- Running network update for timestep 124 ---
# Timestep 124 bump peak: (1, 7)
#
# --- Running network update for timestep 125 ---
# Timestep 125 bump peak: (1, 7)
#
# --- Running network update for timestep 126 ---
# Timestep 126 bump peak: (1, 7)
#
# --- Running network update for timestep 127 ---
# Timestep 127 bump peak: (1, 7)
#
# --- Running network update for timestep 128 ---
# Timestep 128 bump peak: (1, 7)
#
# --- Running network update for timestep 129 ---
# Timestep 129 bump peak: (1, 7)
#
# --- Running network update for timestep 130 ---
# Timestep 130 bump peak: (1, 7)
#
# --- Running network update for timestep 131 ---
# Timestep 131 bump peak: (1, 7)
#
# --- Running network update for timestep 132 ---
# Timestep 132 bump peak: (1, 7)
#
# --- Running network update for timestep 133 ---
# Timestep 133 bump peak: (1, 7)
#
# --- Running network update for timestep 134 ---
# Timestep 134 bump peak: (1, 7)
#
# --- Running network update for timestep 135 ---
# Timestep 135 bump peak: (1, 7)
#
# --- Running network update for timestep 136 ---
# Timestep 136 bump peak: (1, 7)
#
# --- Running network update for timestep 137 ---
# Timestep 137 bump peak: (1, 7)
#
# --- Running network update for timestep 138 ---
# Timestep 138 bump peak: (1, 7)
#
# --- Running network update for timestep 139 ---
# Timestep 139 bump peak: (1, 7)
#
# --- Running network update for timestep 140 ---
# Timestep 140 bump peak: (1, 7)
#
# --- Running network update for timestep 141 ---
# Timestep 141 bump peak: (1, 7)
#
# --- Running network update for timestep 142 ---
# Timestep 142 bump peak: (1, 7)
#
# --- Running network update for timestep 143 ---
# Timestep 143 bump peak: (1, 7)
#
# --- Running network update for timestep 144 ---
# Timestep 144 bump peak: (1, 7)
#
# --- Running network update for timestep 145 ---
# Timestep 145 bump peak: (1, 7)
#
# --- Running network update for timestep 146 ---
# Timestep 146 bump peak: (1, 7)
#
# --- Running network update for timestep 147 ---
# Timestep 147 bump peak: (1, 7)
#
# --- Running network update for timestep 148 ---
# Timestep 148 bump peak: (1, 7)
#
# --- Running network update for timestep 149 ---
# Timestep 149 bump peak: (1, 7)
#
# --- Running network update for timestep 150 ---
# Timestep 150 bump peak: (1, 7)
#
# --- Running network update for timestep 151 ---
# Timestep 151 bump peak: (1, 7)
#
# --- Running network update for timestep 152 ---
# Timestep 152 bump peak: (1, 7)
#
# --- Running network update for timestep 153 ---
# Timestep 153 bump peak: (1, 7)
#
# --- Running network update for timestep 154 ---
# Timestep 154 bump peak: (1, 7)
#
# --- Running network update for timestep 155 ---
# Timestep 155 bump peak: (1, 7)
#
# --- Running network update for timestep 156 ---
# Timestep 156 bump peak: (1, 7)
#
# --- Running network update for timestep 157 ---
# Timestep 157 bump peak: (1, 7)
#
# --- Running network update for timestep 158 ---
# Timestep 158 bump peak: (1, 7)
#
# --- Running network update for timestep 159 ---
# Timestep 159 bump peak: (1, 7)
#
# --- Running network update for timestep 160 ---
# Timestep 160 bump peak: (1, 7)
#
# --- Running network update for timestep 161 ---
# Timestep 161 bump peak: (1, 7)
#
# --- Running network update for timestep 162 ---
# Timestep 162 bump peak: (1, 7)
#
# --- Running network update for timestep 163 ---
# Timestep 163 bump peak: (1, 7)
#
# --- Running network update for timestep 164 ---
# Timestep 164 bump peak: (1, 7)
#
# --- Running network update for timestep 165 ---
# Timestep 165 bump peak: (1, 7)
#
# --- Running network update for timestep 166 ---
# Timestep 166 bump peak: (1, 7)
#
# --- Running network update for timestep 167 ---
# Timestep 167 bump peak: (1, 7)
#
# --- Running network update for timestep 168 ---
# Timestep 168 bump peak: (1, 7)
#
# --- Running network update for timestep 169 ---
# Timestep 169 bump peak: (1, 7)
#
# --- Running network update for timestep 170 ---
# Timestep 170 bump peak: (1, 7)
#
# --- Running network update for timestep 171 ---
# Timestep 171 bump peak: (1, 7)
#
# --- Running network update for timestep 172 ---
# Timestep 172 bump peak: (1, 7)
#
# --- Running network update for timestep 173 ---
# Timestep 173 bump peak: (1, 7)
#
# --- Running network update for timestep 174 ---
# Timestep 174 bump peak: (1, 7)
#
# --- Running network update for timestep 175 ---
# Timestep 175 bump peak: (1, 7)
#
# --- Running network update for timestep 176 ---
# Timestep 176 bump peak: (1, 7)
#
# --- Running network update for timestep 177 ---
# Timestep 177 bump peak: (1, 7)
#
# --- Running network update for timestep 178 ---
# Timestep 178 bump peak: (1, 7)
#
# --- Running network update for timestep 179 ---
# Timestep 179 bump peak: (1, 7)
#
# --- Running network update for timestep 180 ---
# Timestep 180 bump peak: (1, 7)
#
# --- Running network update for timestep 181 ---
# Timestep 181 bump peak: (1, 7)
#
# --- Running network update for timestep 182 ---
# Timestep 182 bump peak: (1, 7)
#
# --- Running network update for timestep 183 ---
# Timestep 183 bump peak: (1, 7)
#
# --- Running network update for timestep 184 ---
# Timestep 184 bump peak: (1, 7)
#
# --- Running network update for timestep 185 ---
# Timestep 185 bump peak: (1, 7)
#
# --- Running network update for timestep 186 ---
# Timestep 186 bump peak: (1, 7)
#
# --- Running network update for timestep 187 ---
# Timestep 187 bump peak: (1, 7)
#
# --- Running network update for timestep 188 ---
# Timestep 188 bump peak: (1, 7)
#
# --- Running network update for timestep 189 ---
# Timestep 189 bump peak: (1, 7)
#
# --- Running network update for timestep 190 ---
# Timestep 190 bump peak: (1, 7)
#
# --- Running network update for timestep 191 ---
# Timestep 191 bump peak: (1, 7)
#
# --- Running network update for timestep 192 ---
# Timestep 192 bump peak: (1, 7)
#
# --- Running network update for timestep 193 ---
# Timestep 193 bump peak: (1, 7)
#
# --- Running network update for timestep 194 ---
# Timestep 194 bump peak: (1, 7)
#
# --- Running network update for timestep 195 ---
# Timestep 195 bump peak: (1, 7)
#
# --- Running network update for timestep 196 ---
# Timestep 196 bump peak: (1, 7)
#
# --- Running network update for timestep 197 ---
# Timestep 197 bump peak: (1, 7)
#
# --- Running network update for timestep 198 ---
# Timestep 198 bump peak: (1, 7)
#
# --- Running network update for timestep 199 ---
# Timestep 199 bump peak: (1, 7)
#
# --- Running network update for timestep 200 ---
# Timestep 200 bump peak: (1, 7)
#
# --- Running network update for timestep 201 ---
# Timestep 201 bump peak: (1, 7)
#
# --- Running network update for timestep 202 ---
# Timestep 202 bump peak: (1, 7)
#
# --- Running network update for timestep 203 ---
# Timestep 203 bump peak: (1, 7)
#
# --- Running network update for timestep 204 ---
# Timestep 204 bump peak: (1, 7)
#
# --- Running network update for timestep 205 ---
# Timestep 205 bump peak: (1, 7)
#
# --- Running network update for timestep 206 ---
# Timestep 206 bump peak: (1, 7)
#
# --- Running network update for timestep 207 ---
# Timestep 207 bump peak: (1, 7)
#
# --- Running network update for timestep 208 ---
# Timestep 208 bump peak: (1, 7)
#
# --- Running network update for timestep 209 ---
# Timestep 209 bump peak: (1, 7)
#
# --- Running network update for timestep 210 ---
# Timestep 210 bump peak: (1, 7)
#
# --- Running network update for timestep 211 ---
# Timestep 211 bump peak: (1, 7)
#
# --- Running network update for timestep 212 ---
# Timestep 212 bump peak: (1, 7)
#
# --- Running network update for timestep 213 ---
# Timestep 213 bump peak: (1, 7)
#
# --- Running network update for timestep 214 ---
# Timestep 214 bump peak: (1, 7)
#
# --- Running network update for timestep 215 ---
# Timestep 215 bump peak: (1, 7)
#
# --- Running network update for timestep 216 ---
# Timestep 216 bump peak: (1, 7)
#
# --- Running network update for timestep 217 ---
# Timestep 217 bump peak: (1, 7)
#
# --- Running network update for timestep 218 ---
# Timestep 218 bump peak: (1, 7)
#
# --- Running network update for timestep 219 ---
# Timestep 219 bump peak: (1, 7)
#
# --- Running network update for timestep 220 ---
# Timestep 220 bump peak: (1, 7)
#
# --- Running network update for timestep 221 ---
# Timestep 221 bump peak: (1, 7)
#
# --- Running network update for timestep 222 ---
# Timestep 222 bump peak: (1, 7)
#
# --- Running network update for timestep 223 ---
# Timestep 223 bump peak: (1, 7)
#
# --- Running network update for timestep 224 ---
# Timestep 224 bump peak: (1, 7)
#
# --- Running network update for timestep 225 ---
# Timestep 225 bump peak: (1, 7)
#
# --- Running network update for timestep 226 ---
# Timestep 226 bump peak: (1, 7)
#
# --- Running network update for timestep 227 ---
# Timestep 227 bump peak: (1, 7)
#
# --- Running network update for timestep 228 ---
# Timestep 228 bump peak: (1, 7)
#
# --- Running network update for timestep 229 ---
# Timestep 229 bump peak: (1, 7)
#
# --- Running network update for timestep 230 ---
# Timestep 230 bump peak: (1, 7)
#
# --- Running network update for timestep 231 ---
# Timestep 231 bump peak: (1, 7)
#
# --- Running network update for timestep 232 ---
# Timestep 232 bump peak: (1, 7)
#
# --- Running network update for timestep 233 ---
# Timestep 233 bump peak: (1, 7)
#
# --- Running network update for timestep 234 ---
# Timestep 234 bump peak: (1, 7)
#
# --- Running network update for timestep 235 ---
# Timestep 235 bump peak: (1, 7)
#
# --- Running network update for timestep 236 ---
# Timestep 236 bump peak: (1, 7)
#
# --- Running network update for timestep 237 ---
# Timestep 237 bump peak: (1, 7)
#
# --- Running network update for timestep 238 ---
# Timestep 238 bump peak: (1, 7)
#
# --- Running network update for timestep 239 ---
# Timestep 239 bump peak: (1, 7)
#
# --- Running network update for timestep 240 ---
# Timestep 240 bump peak: (1, 7)
#
# --- Running network update for timestep 241 ---
# Timestep 241 bump peak: (1, 7)
#
# --- Running network update for timestep 242 ---
# Timestep 242 bump peak: (1, 7)
#
# --- Running network update for timestep 243 ---
# Timestep 243 bump peak: (1, 7)
#
# --- Running network update for timestep 244 ---
# Timestep 244 bump peak: (1, 7)
#
# --- Running network update for timestep 245 ---
# Timestep 245 bump peak: (1, 7)
#
# --- Running network update for timestep 246 ---
# Timestep 246 bump peak: (1, 7)
#
# --- Running network update for timestep 247 ---
# Timestep 247 bump peak: (1, 7)
#
# --- Running network update for timestep 248 ---
# Timestep 248 bump peak: (1, 7)
#
# --- Running network update for timestep 249 ---
# Timestep 249 bump peak: (1, 7)
#
# --- Running network update for timestep 250 ---
# Timestep 250 bump peak: (1, 7)
#
# --- Running network update for timestep 251 ---
# Timestep 251 bump peak: (1, 7)
#
# --- Running network update for timestep 252 ---
# Timestep 252 bump peak: (1, 7)
#
# --- Running network update for timestep 253 ---
# Timestep 253 bump peak: (1, 7)
#
# --- Running network update for timestep 254 ---
# Timestep 254 bump peak: (1, 7)
#
# --- Running network update for timestep 255 ---
# Timestep 255 bump peak: (1, 7)
#
# --- Running network update for timestep 256 ---
# Timestep 256 bump peak: (1, 7)
#
# --- Running network update for timestep 257 ---
# Timestep 257 bump peak: (1, 7)
#
# --- Running network update for timestep 258 ---
# Timestep 258 bump peak: (1, 7)
#
# --- Running network update for timestep 259 ---
# Timestep 259 bump peak: (1, 7)
#
# --- Running network update for timestep 260 ---
# Timestep 260 bump peak: (1, 7)
#
# --- Running network update for timestep 261 ---
# Timestep 261 bump peak: (1, 7)
#
# --- Running network update for timestep 262 ---
# Timestep 262 bump peak: (1, 7)
#
# --- Running network update for timestep 263 ---
# Timestep 263 bump peak: (1, 7)
#
# --- Running network update for timestep 264 ---
# Timestep 264 bump peak: (1, 7)
#
# --- Running network update for timestep 265 ---
# Timestep 265 bump peak: (1, 7)
#
# --- Running network update for timestep 266 ---
# Timestep 266 bump peak: (1, 7)
#
# --- Running network update for timestep 267 ---
# Timestep 267 bump peak: (1, 7)
#
# --- Running network update for timestep 268 ---
# Timestep 268 bump peak: (1, 6)
#
# --- Running network update for timestep 269 ---
# Timestep 269 bump peak: (1, 6)
#
# --- Running network update for timestep 270 ---
# Timestep 270 bump peak: (1, 6)
#
# --- Running network update for timestep 271 ---
# Timestep 271 bump peak: (1, 6)
#
# --- Running network update for timestep 272 ---
# Timestep 272 bump peak: (1, 6)
#
# --- Running network update for timestep 273 ---
# Timestep 273 bump peak: (1, 6)
#
# --- Running network update for timestep 274 ---
# Timestep 274 bump peak: (1, 6)
#
# --- Running network update for timestep 275 ---
# Timestep 275 bump peak: (1, 6)
#
# --- Running network update for timestep 276 ---
# Timestep 276 bump peak: (1, 6)
#
# --- Running network update for timestep 277 ---
# Timestep 277 bump peak: (1, 6)
#
# --- Running network update for timestep 278 ---
# Timestep 278 bump peak: (1, 6)
#
# --- Running network update for timestep 279 ---
# Timestep 279 bump peak: (1, 6)
#
# --- Running network update for timestep 280 ---
# Timestep 280 bump peak: (1, 6)
#
# --- Running network update for timestep 281 ---
# Timestep 281 bump peak: (1, 6)
#
# --- Running network update for timestep 282 ---
# Timestep 282 bump peak: (1, 6)
#
# --- Running network update for timestep 283 ---
# Timestep 283 bump peak: (1, 6)
#
# --- Running network update for timestep 284 ---
# Timestep 284 bump peak: (1, 6)
#
# --- Running network update for timestep 285 ---
# Timestep 285 bump peak: (1, 6)
#
# --- Running network update for timestep 286 ---
# Timestep 286 bump peak: (1, 6)
#
# --- Running network update for timestep 287 ---
# Timestep 287 bump peak: (1, 6)
#
# --- Running network update for timestep 288 ---
# Timestep 288 bump peak: (1, 6)
#
# --- Running network update for timestep 289 ---
# Timestep 289 bump peak: (1, 6)
#
# --- Running network update for timestep 290 ---
# Timestep 290 bump peak: (1, 6)
#
# --- Running network update for timestep 291 ---
# Timestep 291 bump peak: (1, 6)
#
# --- Running network update for timestep 292 ---
# Timestep 292 bump peak: (1, 6)
#
# --- Running network update for timestep 293 ---
# Timestep 293 bump peak: (1, 6)
#
# --- Running network update for timestep 294 ---
# Timestep 294 bump peak: (1, 6)
#
# --- Running network update for timestep 295 ---
# Timestep 295 bump peak: (1, 6)
#
# --- Running network update for timestep 296 ---
# Timestep 296 bump peak: (1, 6)
#
# --- Running network update for timestep 297 ---
# Timestep 297 bump peak: (1, 6)
#
# --- Running network update for timestep 298 ---
# Timestep 298 bump peak: (1, 6)
#
# --- Running network update for timestep 299 ---
# Timestep 299 bump peak: (1, 6)
#
# --- Running network update for timestep 300 ---
# Timestep 300 bump peak: (1, 6)
#
# --- Running network update for timestep 301 ---
# Timestep 301 bump peak: (1, 6)
#
# --- Running network update for timestep 302 ---
# Timestep 302 bump peak: (1, 6)
#
# --- Running network update for timestep 303 ---
# Timestep 303 bump peak: (1, 6)
#
# --- Running network update for timestep 304 ---
# Timestep 304 bump peak: (1, 6)
#
# --- Running network update for timestep 305 ---
# Timestep 305 bump peak: (1, 6)
#
# --- Running network update for timestep 306 ---
# Timestep 306 bump peak: (1, 6)
#
# --- Running network update for timestep 307 ---
# Timestep 307 bump peak: (1, 6)
#
# --- Running network update for timestep 308 ---
# Timestep 308 bump peak: (1, 6)
#
# --- Running network update for timestep 309 ---
# Timestep 309 bump peak: (1, 6)
#
# --- Running network update for timestep 310 ---
# Timestep 310 bump peak: (1, 6)
#
# --- Running network update for timestep 311 ---
# Timestep 311 bump peak: (1, 6)
#
# --- Running network update for timestep 312 ---
# Timestep 312 bump peak: (1, 6)
#
# --- Running network update for timestep 313 ---
# Timestep 313 bump peak: (1, 6)
#
# --- Running network update for timestep 314 ---
# Timestep 314 bump peak: (1, 6)
#
# --- Running network update for timestep 315 ---
# Timestep 315 bump peak: (1, 6)
#
# --- Running network update for timestep 316 ---
# Timestep 316 bump peak: (1, 6)
#
# --- Running network update for timestep 317 ---
# Timestep 317 bump peak: (1, 6)
#
# --- Running network update for timestep 318 ---
# Timestep 318 bump peak: (1, 6)
#
# --- Running network update for timestep 319 ---
# Timestep 319 bump peak: (1, 6)
#
# --- Running network update for timestep 320 ---
# Timestep 320 bump peak: (1, 6)
#
# --- Running network update for timestep 321 ---
# Timestep 321 bump peak: (1, 6)
#
# --- Running network update for timestep 322 ---
# Timestep 322 bump peak: (1, 6)
#
# --- Running network update for timestep 323 ---
# Timestep 323 bump peak: (1, 6)
#
# --- Running network update for timestep 324 ---
# Timestep 324 bump peak: (1, 6)
#
# --- Running network update for timestep 325 ---
# Timestep 325 bump peak: (1, 6)
#
# --- Running network update for timestep 326 ---
# Timestep 326 bump peak: (1, 6)
#
# --- Running network update for timestep 327 ---
# Timestep 327 bump peak: (1, 6)
#
# --- Running network update for timestep 328 ---
# Timestep 328 bump peak: (1, 6)
#
# --- Running network update for timestep 329 ---
# Timestep 329 bump peak: (1, 6)
#
# --- Running network update for timestep 330 ---
# Timestep 330 bump peak: (1, 6)
#
# --- Running network update for timestep 331 ---
# Timestep 331 bump peak: (1, 6)
#
# --- Running network update for timestep 332 ---
# Timestep 332 bump peak: (1, 6)
#
# --- Running network update for timestep 333 ---
# Timestep 333 bump peak: (1, 6)
#
# --- Running network update for timestep 334 ---
# Timestep 334 bump peak: (1, 6)
#
# --- Running network update for timestep 335 ---
# Timestep 335 bump peak: (1, 6)
#
# --- Running network update for timestep 336 ---
# Timestep 336 bump peak: (1, 6)
#
# --- Running network update for timestep 337 ---
# Timestep 337 bump peak: (1, 6)
#
# --- Running network update for timestep 338 ---
# Timestep 338 bump peak: (1, 6)
#
# --- Running network update for timestep 339 ---
# Timestep 339 bump peak: (1, 6)
#
# --- Running network update for timestep 340 ---
# Timestep 340 bump peak: (1, 6)
#
# --- Running network update for timestep 341 ---
# Timestep 341 bump peak: (1, 6)
#
# --- Running network update for timestep 342 ---
# Timestep 342 bump peak: (1, 6)
#
# --- Running network update for timestep 343 ---
# Timestep 343 bump peak: (1, 6)
#
# --- Running network update for timestep 344 ---
# Timestep 344 bump peak: (1, 6)
#
# --- Running network update for timestep 345 ---
# Timestep 345 bump peak: (1, 6)
#
# --- Running network update for timestep 346 ---
# Timestep 346 bump peak: (1, 6)
#
# --- Running network update for timestep 347 ---
# Timestep 347 bump peak: (1, 6)
#
# --- Running network update for timestep 348 ---
# Timestep 348 bump peak: (1, 6)
#
# --- Running network update for timestep 349 ---
# Timestep 349 bump peak: (1, 6)
#
# --- Running network update for timestep 350 ---
# Timestep 350 bump peak: (1, 6)
#
# --- Running network update for timestep 351 ---
# Timestep 351 bump peak: (1, 6)
#
# --- Running network update for timestep 352 ---
# Timestep 352 bump peak: (1, 6)
#
# --- Running network update for timestep 353 ---
# Timestep 353 bump peak: (1, 6)
#
# --- Running network update for timestep 354 ---
# Timestep 354 bump peak: (1, 6)
#
# --- Running network update for timestep 355 ---
# Timestep 355 bump peak: (1, 6)
#
# --- Running network update for timestep 356 ---
# Timestep 356 bump peak: (1, 6)
#
# --- Running network update for timestep 357 ---
# Timestep 357 bump peak: (1, 6)
#
# --- Running network update for timestep 358 ---
# Timestep 358 bump peak: (1, 6)
#
# --- Running network update for timestep 359 ---
# Timestep 359 bump peak: (1, 6)
#
# --- Running network update for timestep 360 ---
# Timestep 360 bump peak: (1, 6)
#
# --- Running network update for timestep 361 ---
# Timestep 361 bump peak: (1, 6)
#
# --- Running network update for timestep 362 ---
# Timestep 362 bump peak: (1, 6)
#
# --- Running network update for timestep 363 ---
# Timestep 363 bump peak: (2, 6)
#
# --- Running network update for timestep 364 ---
# Timestep 364 bump peak: (2, 6)
#
# --- Running network update for timestep 365 ---
# Timestep 365 bump peak: (2, 6)
#
# --- Running network update for timestep 366 ---
# Timestep 366 bump peak: (2, 6)
#
# --- Running network update for timestep 367 ---
# Timestep 367 bump peak: (2, 6)
#
# --- Running network update for timestep 368 ---
# Timestep 368 bump peak: (2, 6)
#
# --- Running network update for timestep 369 ---
# Timestep 369 bump peak: (2, 6)
#
# --- Running network update for timestep 370 ---
# Timestep 370 bump peak: (2, 6)
#
# --- Running network update for timestep 371 ---
# Timestep 371 bump peak: (2, 6)
#
# --- Running network update for timestep 372 ---
# Timestep 372 bump peak: (2, 6)
#
# --- Running network update for timestep 373 ---
# Timestep 373 bump peak: (2, 6)
#
# --- Running network update for timestep 374 ---
# Timestep 374 bump peak: (2, 6)
#
# --- Running network update for timestep 375 ---
# Timestep 375 bump peak: (2, 6)
#
# --- Running network update for timestep 376 ---
# Timestep 376 bump peak: (2, 6)
#
# --- Running network update for timestep 377 ---
# Timestep 377 bump peak: (2, 6)
#
# --- Running network update for timestep 378 ---
# Timestep 378 bump peak: (2, 6)
#
# --- Running network update for timestep 379 ---
# Timestep 379 bump peak: (2, 6)
#
# --- Running network update for timestep 380 ---
# Timestep 380 bump peak: (2, 6)
#
# --- Running network update for timestep 381 ---
# Timestep 381 bump peak: (2, 6)
#
# --- Running network update for timestep 382 ---
# Timestep 382 bump peak: (2, 6)
#
# --- Running network update for timestep 383 ---
# Timestep 383 bump peak: (2, 6)
#
# --- Running network update for timestep 384 ---
# Timestep 384 bump peak: (2, 6)
#
# --- Running network update for timestep 385 ---
# Timestep 385 bump peak: (2, 6)
#
# --- Running network update for timestep 386 ---
# Timestep 386 bump peak: (2, 6)
#
# --- Running network update for timestep 387 ---
# Timestep 387 bump peak: (2, 6)
#
# --- Running network update for timestep 388 ---
# Timestep 388 bump peak: (2, 6)
#
# --- Running network update for timestep 389 ---
# Timestep 389 bump peak: (2, 6)
#
# --- Running network update for timestep 390 ---
# Timestep 390 bump peak: (2, 6)
#
# --- Running network update for timestep 391 ---
# Timestep 391 bump peak: (2, 6)
#
# --- Running network update for timestep 392 ---
# Timestep 392 bump peak: (2, 6)
#
# --- Running network update for timestep 393 ---
# Timestep 393 bump peak: (2, 6)
#
# --- Running network update for timestep 394 ---
# Timestep 394 bump peak: (2, 6)
#
# --- Running network update for timestep 395 ---
# Timestep 395 bump peak: (2, 6)
#
# --- Running network update for timestep 396 ---
# Timestep 396 bump peak: (2, 6)
#
# --- Running network update for timestep 397 ---
# Timestep 397 bump peak: (2, 6)
#
# --- Running network update for timestep 398 ---
# Timestep 398 bump peak: (2, 6)
#
# --- Running network update for timestep 399 ---
# Timestep 399 bump peak: (3, 6)
#
# --- Running network update for timestep 400 ---
# Timestep 400 bump peak: (3, 6)
#
# --- Running network update for timestep 401 ---
# Timestep 401 bump peak: (3, 6)
#
# --- Running network update for timestep 402 ---
# Timestep 402 bump peak: (3, 6)
#
# --- Running network update for timestep 403 ---
# Timestep 403 bump peak: (3, 6)
#
# --- Running network update for timestep 404 ---
# Timestep 404 bump peak: (3, 6)
#
# --- Running network update for timestep 405 ---
# Timestep 405 bump peak: (3, 6)
#
# --- Running network update for timestep 406 ---
# Timestep 406 bump peak: (3, 6)
#
# --- Running network update for timestep 407 ---
# Timestep 407 bump peak: (3, 6)
#
# --- Running network update for timestep 408 ---
# Timestep 408 bump peak: (3, 6)
#
# --- Running network update for timestep 409 ---
# Timestep 409 bump peak: (3, 6)
#
# --- Running network update for timestep 410 ---
# Timestep 410 bump peak: (3, 6)
#
# --- Running network update for timestep 411 ---
# Timestep 411 bump peak: (3, 6)
#
# --- Running network update for timestep 412 ---
# Timestep 412 bump peak: (3, 6)
#
# --- Running network update for timestep 413 ---
# Timestep 413 bump peak: (3, 6)
#
# --- Running network update for timestep 414 ---
# Timestep 414 bump peak: (3, 6)
#
# --- Running network update for timestep 415 ---
# Timestep 415 bump peak: (3, 6)
#
# --- Running network update for timestep 416 ---
# Timestep 416 bump peak: (3, 6)
#
# --- Running network update for timestep 417 ---
# Timestep 417 bump peak: (3, 6)
#
# --- Running network update for timestep 418 ---
# Timestep 418 bump peak: (3, 6)
#
# --- Running network update for timestep 419 ---
# Timestep 419 bump peak: (3, 6)
#
# --- Running network update for timestep 420 ---
# Timestep 420 bump peak: (3, 6)
#
# --- Running network update for timestep 421 ---
# Timestep 421 bump peak: (3, 6)
#
# --- Running network update for timestep 422 ---
# Timestep 422 bump peak: (3, 6)
#
# --- Running network update for timestep 423 ---
# Timestep 423 bump peak: (3, 6)
#
# --- Running network update for timestep 424 ---
# Timestep 424 bump peak: (3, 6)
#
# --- Running network update for timestep 425 ---
# Timestep 425 bump peak: (3, 6)
#
# --- Running network update for timestep 426 ---
# Timestep 426 bump peak: (3, 6)
#
# --- Running network update for timestep 427 ---
# Timestep 427 bump peak: (3, 6)
#
# --- Running network update for timestep 428 ---
# Timestep 428 bump peak: (3, 6)
#
# --- Running network update for timestep 429 ---
# Timestep 429 bump peak: (3, 6)
#
# --- Running network update for timestep 430 ---
# Timestep 430 bump peak: (3, 6)
#
# --- Running network update for timestep 431 ---
# Timestep 431 bump peak: (3, 6)
#
# --- Running network update for timestep 432 ---
# Timestep 432 bump peak: (3, 6)
#
# --- Running network update for timestep 433 ---
# Timestep 433 bump peak: (3, 6)
#
# --- Running network update for timestep 434 ---
# Timestep 434 bump peak: (3, 6)
#
# --- Running network update for timestep 435 ---
# Timestep 435 bump peak: (3, 6)
#
# --- Running network update for timestep 436 ---
# Timestep 436 bump peak: (3, 6)
#
# --- Running network update for timestep 437 ---
# Timestep 437 bump peak: (3, 6)
#
# --- Running network update for timestep 438 ---
# Timestep 438 bump peak: (3, 6)
#
# --- Running network update for timestep 439 ---
# Timestep 439 bump peak: (2, 6)
#
# --- Running network update for timestep 440 ---
# Timestep 440 bump peak: (2, 6)
#
# --- Running network update for timestep 441 ---
# Timestep 441 bump peak: (2, 6)
#
# --- Running network update for timestep 442 ---
# Timestep 442 bump peak: (2, 6)
#
# --- Running network update for timestep 443 ---
# Timestep 443 bump peak: (2, 6)
#
# --- Running network update for timestep 444 ---
# Timestep 444 bump peak: (2, 6)
#
# --- Running network update for timestep 445 ---
# Timestep 445 bump peak: (2, 6)
#
# --- Running network update for timestep 446 ---
# Timestep 446 bump peak: (2, 6)
#
# --- Running network update for timestep 447 ---
# Timestep 447 bump peak: (2, 6)
#
# --- Running network update for timestep 448 ---
# Timestep 448 bump peak: (2, 6)
#
# --- Running network update for timestep 449 ---
# Timestep 449 bump peak: (2, 6)
#
# --- Running network update for timestep 450 ---
# Timestep 450 bump peak: (2, 6)
#
# --- Running network update for timestep 451 ---
# Timestep 451 bump peak: (2, 6)
#
# --- Running network update for timestep 452 ---
# Timestep 452 bump peak: (2, 6)
#
# --- Running network update for timestep 453 ---
# Timestep 453 bump peak: (2, 6)
#
# --- Running network update for timestep 454 ---
# Timestep 454 bump peak: (2, 6)
#
# --- Running network update for timestep 455 ---
# Timestep 455 bump peak: (2, 6)
#
# --- Running network update for timestep 456 ---
# Timestep 456 bump peak: (3, 5)
#
# --- Running network update for timestep 457 ---
# Timestep 457 bump peak: (2, 6)
#
# --- Running network update for timestep 458 ---
# Timestep 458 bump peak: (2, 6)
#
# --- Running network update for timestep 459 ---
# Timestep 459 bump peak: (3, 5)
#
# --- Running network update for timestep 460 ---
# Timestep 460 bump peak: (3, 5)
#
# --- Running network update for timestep 461 ---
# Timestep 461 bump peak: (2, 6)
#
# --- Running network update for timestep 462 ---
# Timestep 462 bump peak: (2, 6)
#
# --- Running network update for timestep 463 ---
# Timestep 463 bump peak: (2, 6)
#
# --- Running network update for timestep 464 ---
# Timestep 464 bump peak: (2, 6)
#
# --- Running network update for timestep 465 ---
# Timestep 465 bump peak: (2, 6)
#
# --- Running network update for timestep 466 ---
# Timestep 466 bump peak: (2, 6)
#
# --- Running network update for timestep 467 ---
# Timestep 467 bump peak: (2, 6)
#
# --- Running network update for timestep 468 ---
# Timestep 468 bump peak: (2, 6)
#
# --- Running network update for timestep 469 ---
# Timestep 469 bump peak: (2, 6)
#
# --- Running network update for timestep 470 ---
# Timestep 470 bump peak: (2, 6)
#
# --- Running network update for timestep 471 ---
# Timestep 471 bump peak: (2, 6)
#
# --- Running network update for timestep 472 ---
# Timestep 472 bump peak: (2, 6)
#
# --- Running network update for timestep 473 ---
# Timestep 473 bump peak: (2, 6)
#
# --- Running network update for timestep 474 ---
# Timestep 474 bump peak: (2, 6)
#
# --- Running network update for timestep 475 ---
# Timestep 475 bump peak: (2, 6)
#
# --- Running network update for timestep 476 ---
# Timestep 476 bump peak: (2, 6)
#
# --- Running network update for timestep 477 ---
# Timestep 477 bump peak: (2, 6)
#
# --- Running network update for timestep 478 ---
# Timestep 478 bump peak: (2, 6)
#
# --- Running network update for timestep 479 ---
# Timestep 479 bump peak: (2, 6)
#
# --- Running network update for timestep 480 ---
# Timestep 480 bump peak: (2, 6)
#
# --- Running network update for timestep 481 ---
# Timestep 481 bump peak: (2, 6)
#
# --- Running network update for timestep 482 ---
# Timestep 482 bump peak: (2, 6)
#
# --- Running network update for timestep 483 ---
# Timestep 483 bump peak: (2, 6)
#
# --- Running network update for timestep 484 ---
# Timestep 484 bump peak: (2, 6)
#
# --- Running network update for timestep 485 ---
# Timestep 485 bump peak: (2, 6)
#
# --- Running network update for timestep 486 ---
# Timestep 486 bump peak: (2, 6)
#
# --- Running network update for timestep 487 ---
# Timestep 487 bump peak: (2, 6)
#
# --- Running network update for timestep 488 ---
# Timestep 488 bump peak: (2, 6)
#
# --- Running network update for timestep 489 ---
# Timestep 489 bump peak: (2, 6)
#
# --- Running network update for timestep 490 ---
# Timestep 490 bump peak: (2, 6)
#
# --- Running network update for timestep 491 ---
# Timestep 491 bump peak: (2, 6)
#
# --- Running network update for timestep 492 ---
# Timestep 492 bump peak: (2, 6)
#
# --- Running network update for timestep 493 ---
# Timestep 493 bump peak: (2, 6)
#
# --- Running network update for timestep 494 ---
# Timestep 494 bump peak: (2, 6)
#
# --- Running network update for timestep 495 ---
# Timestep 495 bump peak: (2, 6)
#
# --- Running network update for timestep 496 ---
# Timestep 496 bump peak: (2, 6)
#
# --- Running network update for timestep 497 ---
# Timestep 497 bump peak: (2, 6)
#
# --- Running network update for timestep 498 ---
# Timestep 498 bump peak: (2, 6)
#
# --- Running network update for timestep 499 ---
# Timestep 499 bump peak: (2, 6)
#
# --- Running network update for timestep 500 ---
# Timestep 500 bump peak: (2, 6)
#
# --- Running network update for timestep 501 ---
# Timestep 501 bump peak: (2, 6)
#
# --- Running network update for timestep 502 ---
# Timestep 502 bump peak: (2, 6)
#
# --- Running network update for timestep 503 ---
# Timestep 503 bump peak: (2, 6)
#
# --- Running network update for timestep 504 ---
# Timestep 504 bump peak: (2, 6)
#
# --- Running network update for timestep 505 ---
# Timestep 505 bump peak: (2, 6)
#
# --- Running network update for timestep 506 ---
# Timestep 506 bump peak: (2, 6)
#
# --- Running network update for timestep 507 ---
# Timestep 507 bump peak: (2, 6)
#
# --- Running network update for timestep 508 ---
# Timestep 508 bump peak: (2, 6)
#
# --- Running network update for timestep 509 ---
# Timestep 509 bump peak: (2, 6)
#
# --- Running network update for timestep 510 ---
# Timestep 510 bump peak: (2, 6)
#
# --- Running network update for timestep 511 ---
# Timestep 511 bump peak: (2, 6)
#
# --- Running network update for timestep 512 ---
# Timestep 512 bump peak: (2, 6)
#
# --- Running network update for timestep 513 ---
# Timestep 513 bump peak: (2, 6)
#
# --- Running network update for timestep 514 ---
# Timestep 514 bump peak: (2, 6)
#
# --- Running network update for timestep 515 ---
# Timestep 515 bump peak: (2, 6)
#
# --- Running network update for timestep 516 ---
# Timestep 516 bump peak: (2, 6)
#
# --- Running network update for timestep 517 ---
# Timestep 517 bump peak: (2, 6)
#
# --- Running network update for timestep 518 ---
# Timestep 518 bump peak: (2, 6)
#
# --- Running network update for timestep 519 ---
# Timestep 519 bump peak: (2, 6)
#
# --- Running network update for timestep 520 ---
# Timestep 520 bump peak: (2, 6)
#
# --- Running network update for timestep 521 ---
# Timestep 521 bump peak: (2, 6)
#
# --- Running network update for timestep 522 ---
# Timestep 522 bump peak: (2, 6)
#
# --- Running network update for timestep 523 ---
# Timestep 523 bump peak: (2, 6)
#
# --- Running network update for timestep 524 ---
# Timestep 524 bump peak: (2, 6)
#
# --- Running network update for timestep 525 ---
# Timestep 525 bump peak: (2, 6)
#
# --- Running network update for timestep 526 ---
# Timestep 526 bump peak: (2, 6)
#
# --- Running network update for timestep 527 ---
# Timestep 527 bump peak: (2, 6)
#
# --- Running network update for timestep 528 ---
# Timestep 528 bump peak: (2, 6)
#
# --- Running network update for timestep 529 ---
# Timestep 529 bump peak: (2, 6)
#
# --- Running network update for timestep 530 ---
# Timestep 530 bump peak: (2, 6)
#
# --- Running network update for timestep 531 ---
# Timestep 531 bump peak: (2, 6)
#
# --- Running network update for timestep 532 ---
# Timestep 532 bump peak: (2, 6)
#
# --- Running network update for timestep 533 ---
# Timestep 533 bump peak: (2, 5)
#
# --- Running network update for timestep 534 ---
# Timestep 534 bump peak: (2, 5)
#
# --- Running network update for timestep 535 ---
# Timestep 535 bump peak: (2, 5)
#
# --- Running network update for timestep 536 ---
# Timestep 536 bump peak: (2, 5)
#
# --- Running network update for timestep 537 ---
# Timestep 537 bump peak: (2, 5)
#
# --- Running network update for timestep 538 ---
# Timestep 538 bump peak: (2, 5)
#
# --- Running network update for timestep 539 ---
# Timestep 539 bump peak: (2, 5)
#
# --- Running network update for timestep 540 ---
# Timestep 540 bump peak: (2, 5)
#
# --- Running network update for timestep 541 ---
# Timestep 541 bump peak: (2, 5)
#
# --- Running network update for timestep 542 ---
# Timestep 542 bump peak: (2, 5)
#
# --- Running network update for timestep 543 ---
# Timestep 543 bump peak: (2, 5)
#
# --- Running network update for timestep 544 ---
# Timestep 544 bump peak: (2, 5)
#
# --- Running network update for timestep 545 ---
# Timestep 545 bump peak: (2, 5)
#
# --- Running network update for timestep 546 ---
# Timestep 546 bump peak: (2, 5)
#
# --- Running network update for timestep 547 ---
# Timestep 547 bump peak: (2, 5)
#
# --- Running network update for timestep 548 ---
# Timestep 548 bump peak: (2, 5)
#
# --- Running network update for timestep 549 ---
# Timestep 549 bump peak: (2, 5)
#
# --- Running network update for timestep 550 ---
# Timestep 550 bump peak: (2, 5)
#
# --- Running network update for timestep 551 ---
# Timestep 551 bump peak: (2, 5)
#
# --- Running network update for timestep 552 ---
# Timestep 552 bump peak: (2, 5)
#
# --- Running network update for timestep 553 ---
# Timestep 553 bump peak: (2, 5)
#
# --- Running network update for timestep 554 ---
# Timestep 554 bump peak: (2, 5)
#
# --- Running network update for timestep 555 ---
# Timestep 555 bump peak: (2, 5)
#
# --- Running network update for timestep 556 ---
# Timestep 556 bump peak: (2, 5)
#
# --- Running network update for timestep 557 ---
# Timestep 557 bump peak: (2, 5)
#
# --- Running network update for timestep 558 ---
# Timestep 558 bump peak: (2, 5)
#
# --- Running network update for timestep 559 ---
# Timestep 559 bump peak: (2, 5)
#
# --- Running network update for timestep 560 ---
# Timestep 560 bump peak: (2, 5)
#
# --- Running network update for timestep 561 ---
# Timestep 561 bump peak: (2, 5)
#
# --- Running network update for timestep 562 ---
# Timestep 562 bump peak: (2, 5)
#
# --- Running network update for timestep 563 ---
# Timestep 563 bump peak: (2, 5)
#
# --- Running network update for timestep 564 ---
# Timestep 564 bump peak: (2, 5)
#
# --- Running network update for timestep 565 ---
# Timestep 565 bump peak: (2, 4)
#
# --- Running network update for timestep 566 ---
# Timestep 566 bump peak: (2, 4)
#
# --- Running network update for timestep 567 ---
# Timestep 567 bump peak: (2, 4)
#
# --- Running network update for timestep 568 ---
# Timestep 568 bump peak: (2, 4)
#
# --- Running network update for timestep 569 ---
# Timestep 569 bump peak: (2, 4)
#
# --- Running network update for timestep 570 ---
# Timestep 570 bump peak: (2, 4)
#
# --- Running network update for timestep 571 ---
# Timestep 571 bump peak: (2, 4)
#
# --- Running network update for timestep 572 ---
# Timestep 572 bump peak: (2, 4)
#
# --- Running network update for timestep 573 ---
# Timestep 573 bump peak: (2, 4)
#
# --- Running network update for timestep 574 ---
# Timestep 574 bump peak: (2, 4)
#
# --- Running network update for timestep 575 ---
# Timestep 575 bump peak: (2, 4)
#
# --- Running network update for timestep 576 ---
# Timestep 576 bump peak: (2, 4)
#
# --- Running network update for timestep 577 ---
# Timestep 577 bump peak: (2, 4)
#
# --- Running network update for timestep 578 ---
# Timestep 578 bump peak: (2, 4)
#
# --- Running network update for timestep 579 ---
# Timestep 579 bump peak: (2, 4)
#
# --- Running network update for timestep 580 ---
# Timestep 580 bump peak: (2, 4)
#
# --- Running network update for timestep 581 ---
# Timestep 581 bump peak: (2, 4)
#
# --- Running network update for timestep 582 ---
# Timestep 582 bump peak: (2, 4)
#
# --- Running network update for timestep 583 ---
# Timestep 583 bump peak: (2, 4)
#
# --- Running network update for timestep 584 ---
# Timestep 584 bump peak: (2, 4)
#
# --- Running network update for timestep 585 ---
# Timestep 585 bump peak: (2, 4)
#
# --- Running network update for timestep 586 ---
# Timestep 586 bump peak: (2, 4)
#
# --- Running network update for timestep 587 ---
# Timestep 587 bump peak: (2, 4)
#
# --- Running network update for timestep 588 ---
# Timestep 588 bump peak: (2, 4)
#
# --- Running network update for timestep 589 ---
# Timestep 589 bump peak: (2, 4)
#
# --- Running network update for timestep 590 ---
# Timestep 590 bump peak: (2, 4)
#
# --- Running network update for timestep 591 ---
# Timestep 591 bump peak: (2, 4)
#
# --- Running network update for timestep 592 ---
# Timestep 592 bump peak: (2, 4)
#
# --- Running network update for timestep 593 ---
# Timestep 593 bump peak: (2, 4)
#
# --- Running network update for timestep 594 ---
# Timestep 594 bump peak: (2, 4)
#
# --- Running network update for timestep 595 ---
# Timestep 595 bump peak: (2, 4)
#
# --- Running network update for timestep 596 ---
# Timestep 596 bump peak: (2, 4)
#
# --- Running network update for timestep 597 ---
# Timestep 597 bump peak: (2, 4)
#
# --- Running network update for timestep 598 ---
# Timestep 598 bump peak: (2, 4)
#
# --- Running network update for timestep 599 ---
# Timestep 599 bump peak: (2, 4)
#
# --- Running network update for timestep 600 ---
# Timestep 600 bump peak: (2, 4)
#
# --- Running network update for timestep 601 ---
# Timestep 601 bump peak: (2, 4)
#
# --- Running network update for timestep 602 ---
# Timestep 602 bump peak: (2, 4)
#
# --- Running network update for timestep 603 ---
# ...
# Timestep 801 bump peak: (6, 2)
#
# --- Running network update for timestep 802 ---
# Timestep 802 bump peak: (6, 2)
#
# --- Running network update for timestep 803 ---
# Timestep 803 bump peak: (6, 2)
#
# --- Running network update for timestep 804 ---
# Timestep 804 bump peak: (6, 2)
#
# --- Running network update for timestep 805 ---
# Timestep 805 bump peak: (6, 2)
#
# --- Running network update for timestep 806 ---
# Timestep 806 bump peak: (6, 2)
#
# --- Running network update for timestep 807 ---
# Timestep 807 bump peak: (7, 2)
#
# --- Running network update for timestep 808 ---
# Timestep 808 bump peak: (7, 2)
#
# --- Running network update for timestep 809 ---
# Timestep 809 bump peak: (7, 2)
#
# --- Running network update for timestep 810 ---
# Timestep 810 bump peak: (7, 2)
#
# --- Running network update for timestep 811 ---
# Timestep 811 bump peak: (7, 2)
#
# --- Running network update for timestep 812 ---
# Timestep 812 bump peak: (7, 2)
#
# --- Running network update for timestep 813 ---
# Timestep 813 bump peak: (7, 2)
#
# --- Running network update for timestep 814 ---
# Timestep 814 bump peak: (7, 2)
#
# --- Running network update for timestep 815 ---
# Timestep 815 bump peak: (7, 2)
#
# --- Running network update for timestep 816 ---
# Timestep 816 bump peak: (7, 2)
#
# --- Running network update for timestep 817 ---
# Timestep 817 bump peak: (7, 2)
#
# --- Running network update for timestep 818 ---
# Timestep 818 bump peak: (7, 2)
#
# --- Running network update for timestep 819 ---
# Timestep 819 bump peak: (7, 2)
#
# --- Running network update for timestep 820 ---
# Timestep 820 bump peak: (7, 2)
#
# --- Running network update for timestep 821 ---
# Timestep 821 bump peak: (7, 2)
#
# --- Running network update for timestep 822 ---
# Timestep 822 bump peak: (7, 2)
#
# --- Running network update for timestep 823 ---
# Timestep 823 bump peak: (7, 2)
#
# --- Running network update for timestep 824 ---
# Timestep 824 bump peak: (7, 2)
#
# --- Running network update for timestep 825 ---
# Timestep 825 bump peak: (7, 2)
#
# --- Running network update for timestep 826 ---
# Timestep 826 bump peak: (7, 2)
#
# --- Running network update for timestep 827 ---
# Timestep 827 bump peak: (7, 2)
#
# --- Running network update for timestep 828 ---
# Timestep 828 bump peak: (7, 2)
#
# --- Running network update for timestep 829 ---
# Timestep 829 bump peak: (7, 2)
#
# --- Running network update for timestep 830 ---
# Timestep 830 bump peak: (7, 2)
#
# --- Running network update for timestep 831 ---
# Timestep 831 bump peak: (7, 1)
#
# --- Running network update for timestep 832 ---
# Timestep 832 bump peak: (7, 1)
#
# --- Running network update for timestep 833 ---
# Timestep 833 bump peak: (7, 1)
#
# --- Running network update for timestep 834 ---
# Timestep 834 bump peak: (7, 1)
#
# --- Running network update for timestep 835 ---
# Timestep 835 bump peak: (7, 1)
#
# --- Running network update for timestep 836 ---
# Timestep 836 bump peak: (7, 1)
#
# --- Running network update for timestep 837 ---
# Timestep 837 bump peak: (7, 1)
#
# --- Running network update for timestep 838 ---
# Timestep 838 bump peak: (7, 1)
#
# --- Running network update for timestep 839 ---
# Timestep 839 bump peak: (7, 1)
#
# --- Running network update for timestep 840 ---
# Timestep 840 bump peak: (7, 1)
#
# --- Running network update for timestep 841 ---
# Timestep 841 bump peak: (7, 1)
#
# --- Running network update for timestep 842 ---
# Timestep 842 bump peak: (7, 1)
#
# --- Running network update for timestep 843 ---
# Timestep 843 bump peak: (7, 1)
#
# --- Running network update for timestep 844 ---
# Timestep 844 bump peak: (7, 1)
#
# --- Running network update for timestep 845 ---
# Timestep 845 bump peak: (7, 1)
#
# --- Running network update for timestep 846 ---
# Timestep 846 bump peak: (7, 1)
#
# --- Running network update for timestep 847 ---
# Timestep 847 bump peak: (7, 1)
#
# --- Running network update for timestep 848 ---
# Timestep 848 bump peak: (7, 1)
#
# --- Running network update for timestep 849 ---
# Timestep 849 bump peak: (7, 1)
#
# --- Running network update for timestep 850 ---
# Timestep 850 bump peak: (7, 1)
#
# --- Running network update for timestep 851 ---
# Timestep 851 bump peak: (7, 1)
#
# --- Running network update for timestep 852 ---
# Timestep 852 bump peak: (7, 1)
#
# --- Running network update for timestep 853 ---
# Timestep 853 bump peak: (7, 1)
#
# --- Running network update for timestep 854 ---
# Timestep 854 bump peak: (7, 1)
#
# --- Running network update for timestep 855 ---
# Timestep 855 bump peak: (7, 1)
#
# --- Running network update for timestep 856 ---
# Timestep 856 bump peak: (7, 1)
#
# --- Running network update for timestep 857 ---
# Timestep 857 bump peak: (7, 1)
#
# --- Running network update for timestep 858 ---
# Timestep 858 bump peak: (7, 1)
#
# --- Running network update for timestep 859 ---
# Timestep 859 bump peak: (7, 1)
#
# --- Running network update for timestep 860 ---
# Timestep 860 bump peak: (7, 1)
#
# --- Running network update for timestep 861 ---
# Timestep 861 bump peak: (7, 1)
#
# --- Running network update for timestep 862 ---
# Timestep 862 bump peak: (7, 1)
#
# --- Running network update for timestep 863 ---
# Timestep 863 bump peak: (7, 1)
#
# --- Running network update for timestep 864 ---
# Timestep 864 bump peak: (7, 1)
#
# --- Running network update for timestep 865 ---
# Timestep 865 bump peak: (7, 1)
#
# --- Running network update for timestep 866 ---
# Timestep 866 bump peak: (7, 1)
#
# --- Running network update for timestep 867 ---
# Timestep 867 bump peak: (7, 1)
#
# --- Running network update for timestep 868 ---
# Timestep 868 bump peak: (7, 1)
#
# --- Running network update for timestep 869 ---
# Timestep 869 bump peak: (7, 1)
#
# --- Running network update for timestep 870 ---
# Timestep 870 bump peak: (7, 1)
#
# --- Running network update for timestep 871 ---
# Timestep 871 bump peak: (7, 1)
#
# --- Running network update for timestep 872 ---
# Timestep 872 bump peak: (7, 1)
#
# --- Running network update for timestep 873 ---
# Timestep 873 bump peak: (7, 1)
#
# --- Running network update for timestep 874 ---
# Timestep 874 bump peak: (7, 1)
#
# --- Running network update for timestep 875 ---
# Timestep 875 bump peak: (7, 1)
#
# --- Running network update for timestep 876 ---
# Timestep 876 bump peak: (7, 1)
#
# --- Running network update for timestep 877 ---
# Timestep 877 bump peak: (7, 1)
#
# --- Running network update for timestep 878 ---
# Timestep 878 bump peak: (7, 1)
#
# --- Running network update for timestep 879 ---
# Timestep 879 bump peak: (7, 1)
#
# --- Running network update for timestep 880 ---
# Timestep 880 bump peak: (7, 1)
#
# --- Running network update for timestep 881 ---
# Timestep 881 bump peak: (7, 1)
#
# --- Running network update for timestep 882 ---
# Timestep 882 bump peak: (7, 1)
#
# --- Running network update for timestep 883 ---
# Timestep 883 bump peak: (7, 1)
#
# --- Running network update for timestep 884 ---
# Timestep 884 bump peak: (7, 1)
#
# --- Running network update for timestep 885 ---
# Timestep 885 bump peak: (7, 1)
#
# --- Running network update for timestep 886 ---
# Timestep 886 bump peak: (7, 1)
#
# --- Running network update for timestep 887 ---
# Timestep 887 bump peak: (7, 1)
#
# --- Running network update for timestep 888 ---
# Timestep 888 bump peak: (7, 1)
#
# --- Running network update for timestep 889 ---
# Timestep 889 bump peak: (7, 1)
#
# --- Running network update for timestep 890 ---
# Timestep 890 bump peak: (7, 1)
#
# --- Running network update for timestep 891 ---
# Timestep 891 bump peak: (7, 1)
#
# --- Running network update for timestep 892 ---
# Timestep 892 bump peak: (7, 1)
#
# --- Running network update for timestep 893 ---
# Timestep 893 bump peak: (7, 1)
#
# --- Running network update for timestep 894 ---
# Timestep 894 bump peak: (7, 1)
#
# --- Running network update for timestep 895 ---
# Timestep 895 bump peak: (7, 1)
#
# --- Running network update for timestep 896 ---
# Timestep 896 bump peak: (7, 1)
#
# --- Running network update for timestep 897 ---
# Timestep 897 bump peak: (7, 1)
#
# --- Running network update for timestep 898 ---
# Timestep 898 bump peak: (7, 1)
#
# --- Running network update for timestep 899 ---
# Timestep 899 bump peak: (7, 1)
#
# --- Running network update for timestep 900 ---
# Timestep 900 bump peak: (7, 1)
#
# --- Running network update for timestep 901 ---
# Timestep 901 bump peak: (7, 1)
#
# --- Running network update for timestep 902 ---
# Timestep 902 bump peak: (7, 1)
#
# --- Running network update for timestep 903 ---
# Timestep 903 bump peak: (7, 1)
#
# --- Running network update for timestep 904 ---
# Timestep 904 bump peak: (7, 1)
#
# --- Running network update for timestep 905 ---
# Timestep 905 bump peak: (7, 1)
#
# --- Running network update for timestep 906 ---
# Timestep 906 bump peak: (7, 1)
#
# --- Running network update for timestep 907 ---
# Timestep 907 bump peak: (7, 1)
#
# --- Running network update for timestep 908 ---
# Timestep 908 bump peak: (7, 1)
#
# --- Running network update for timestep 909 ---
# Timestep 909 bump peak: (7, 1)
#
# --- Running network update for timestep 910 ---
# Timestep 910 bump peak: (7, 1)
#
# --- Running network update for timestep 911 ---
# Timestep 911 bump peak: (7, 1)
#
# --- Running network update for timestep 912 ---
# Timestep 912 bump peak: (7, 1)
#
# --- Running network update for timestep 913 ---
# Timestep 913 bump peak: (7, 1)
#
# --- Running network update for timestep 914 ---
# Timestep 914 bump peak: (7, 1)
#
# --- Running network update for timestep 915 ---
# Timestep 915 bump peak: (7, 1)
#
# --- Running network update for timestep 916 ---
# Timestep 916 bump peak: (7, 1)
#
# --- Running network update for timestep 917 ---
# Timestep 917 bump peak: (7, 1)
#
# --- Running network update for timestep 918 ---
# Timestep 918 bump peak: (7, 1)
#
# --- Running network update for timestep 919 ---
# Timestep 919 bump peak: (7, 1)
#
# --- Running network update for timestep 920 ---
# Timestep 920 bump peak: (7, 1)
#
# --- Running network update for timestep 921 ---
# Timestep 921 bump peak: (7, 1)
#
# --- Running network update for timestep 922 ---
# Timestep 922 bump peak: (7, 1)
#
# --- Running network update for timestep 923 ---
# Timestep 923 bump peak: (7, 1)
#
# --- Running network update for timestep 924 ---
# Timestep 924 bump peak: (7, 1)
#
# --- Running network update for timestep 925 ---
# Timestep 925 bump peak: (7, 1)
#
# --- Running network update for timestep 926 ---
# Timestep 926 bump peak: (6, 1)
#
# --- Running network update for timestep 927 ---
# Timestep 927 bump peak: (6, 1)
#
# --- Running network update for timestep 928 ---
# Timestep 928 bump peak: (6, 1)
#
# --- Running network update for timestep 929 ---
# Timestep 929 bump peak: (6, 1)
#
# --- Running network update for timestep 930 ---
# Timestep 930 bump peak: (6, 1)
#
# --- Running network update for timestep 931 ---
# Timestep 931 bump peak: (6, 1)
#
# --- Running network update for timestep 932 ---
# Timestep 932 bump peak: (6, 1)
#
# --- Running network update for timestep 933 ---
# Timestep 933 bump peak: (6, 1)
#
# --- Running network update for timestep 934 ---
# Timestep 934 bump peak: (6, 1)
#
# --- Running network update for timestep 935 ---
# Timestep 935 bump peak: (6, 1)
#
# --- Running network update for timestep 936 ---
# Timestep 936 bump peak: (6, 1)
#
# --- Running network update for timestep 937 ---
# Timestep 937 bump peak: (6, 1)
#
# --- Running network update for timestep 938 ---
# Timestep 938 bump peak: (6, 1)
#
# --- Running network update for timestep 939 ---
# Timestep 939 bump peak: (6, 1)
#
# --- Running network update for timestep 940 ---
# Timestep 940 bump peak: (6, 1)
#
# --- Running network update for timestep 941 ---
# Timestep 941 bump peak: (6, 1)
#
# --- Running network update for timestep 942 ---
# Timestep 942 bump peak: (6, 1)
#
# --- Running network update for timestep 943 ---
# Timestep 943 bump peak: (6, 1)
#
# --- Running network update for timestep 944 ---
# Timestep 944 bump peak: (6, 1)
#
# --- Running network update for timestep 945 ---
# Timestep 945 bump peak: (6, 1)
#
# --- Running network update for timestep 946 ---
# Timestep 946 bump peak: (6, 1)
#
# --- Running network update for timestep 947 ---
# Timestep 947 bump peak: (6, 1)
#
# --- Running network update for timestep 948 ---
# Timestep 948 bump peak: (6, 1)
#
# --- Running network update for timestep 949 ---
# Timestep 949 bump peak: (6, 1)
#
# --- Running network update for timestep 950 ---
# Timestep 950 bump peak: (6, 1)
#
# --- Running network update for timestep 951 ---
# Timestep 951 bump peak: (6, 1)
#
# --- Running network update for timestep 952 ---
# Timestep 952 bump peak: (6, 1)
#
# --- Running network update for timestep 953 ---
# Timestep 953 bump peak: (6, 1)
#
# --- Running network update for timestep 954 ---
# Timestep 954 bump peak: (6, 1)
#
# --- Running network update for timestep 955 ---
# Timestep 955 bump peak: (6, 1)
#
# --- Running network update for timestep 956 ---
# Timestep 956 bump peak: (6, 1)
#
# --- Running network update for timestep 957 ---
# Timestep 957 bump peak: (6, 1)
#
# --- Running network update for timestep 958 ---
# Timestep 958 bump peak: (6, 1)
#
# --- Running network update for timestep 959 ---
# Timestep 959 bump peak: (6, 1)
#
# --- Running network update for timestep 960 ---
# Timestep 960 bump peak: (6, 1)
#
# --- Running network update for timestep 961 ---
# Timestep 961 bump peak: (6, 1)
#
# --- Running network update for timestep 962 ---
# Timestep 962 bump peak: (6, 1)
#
# --- Running network update for timestep 963 ---
# Timestep 963 bump peak: (6, 1)
#
# --- Running network update for timestep 964 ---
# Timestep 964 bump peak: (6, 1)
#
# --- Running network update for timestep 965 ---
# Timestep 965 bump peak: (6, 1)
#
# --- Running network update for timestep 966 ---
# Timestep 966 bump peak: (6, 1)
#
# --- Running network update for timestep 967 ---
# Timestep 967 bump peak: (6, 1)
#
# --- Running network update for timestep 968 ---
# Timestep 968 bump peak: (6, 1)
#
# --- Running network update for timestep 969 ---
# Timestep 969 bump peak: (6, 1)
#
# --- Running network update for timestep 970 ---
# Timestep 970 bump peak: (6, 1)
#
# --- Running network update for timestep 971 ---
# Timestep 971 bump peak: (6, 1)
#
# --- Running network update for timestep 972 ---
# Timestep 972 bump peak: (6, 1)
#
# --- Running network update for timestep 973 ---
# Timestep 973 bump peak: (6, 1)
#
# --- Running network update for timestep 974 ---
# Timestep 974 bump peak: (6, 1)
#
# --- Running network update for timestep 975 ---
# Timestep 975 bump peak: (6, 1)
#
# --- Running network update for timestep 976 ---
# Timestep 976 bump peak: (6, 1)
#
# --- Running network update for timestep 977 ---
# Timestep 977 bump peak: (6, 1)
#
# --- Running network update for timestep 978 ---
# Timestep 978 bump peak: (6, 1)
#
# --- Running network update for timestep 979 ---
# Timestep 979 bump peak: (6, 1)
#
# --- Running network update for timestep 980 ---
# Timestep 980 bump peak: (6, 1)
#
# --- Running network update for timestep 981 ---
# Timestep 981 bump peak: (6, 1)
#
# --- Running network update for timestep 982 ---
# Timestep 982 bump peak: (6, 1)
#
# --- Running network update for timestep 983 ---
# Timestep 983 bump peak: (6, 1)
#
# --- Running network update for timestep 984 ---
# Timestep 984 bump peak: (6, 1)
#
# --- Running network update for timestep 985 ---
# Timestep 985 bump peak: (6, 1)
#
# --- Running network update for timestep 986 ---
# Timestep 986 bump peak: (6, 1)
#
# --- Running network update for timestep 987 ---
# Timestep 987 bump peak: (6, 1)
#
# --- Running network update for timestep 988 ---
# Timestep 988 bump peak: (6, 1)
#
# --- Running network update for timestep 989 ---
# Timestep 989 bump peak: (5, 1)
#
# --- Running network update for timestep 990 ---
# Timestep 990 bump peak: (5, 1)
#
# --- Running network update for timestep 991 ---
# Timestep 991 bump peak: (5, 1)
#
# --- Running network update for timestep 992 ---
# Timestep 992 bump peak: (5, 1)
#
# --- Running network update for timestep 993 ---
# Timestep 993 bump peak: (5, 1)
#
# --- Running network update for timestep 994 ---
# Timestep 994 bump peak: (5, 1)
#
# --- Running network update for timestep 995 ---
# Timestep 995 bump peak: (5, 1)
#
# --- Running network update for timestep 996 ---
# Timestep 996 bump peak: (5, 1)
#
# --- Running network update for timestep 997 ---
# Timestep 997 bump peak: (5, 1)
#
# --- Running network update for timestep 998 ---
# Timestep 998 bump peak: (5, 1)
#
# --- Running network update for timestep 999 ---
# Timestep 999 bump peak: (5, 1)
#
# --- Running network update for timestep 1000 ---
# Timestep 1000 bump peak: (5, 1)

# %%
interact(
    show_bump_3D,
    matrix=fixed(results),               # Your bump matrix: shape [timesteps, rows, cols]
    PC_idx=fixed(PC_idx),               # Optional overlay of place cell indices
    timestep=IntSlider(min=0, max=results.shape[0]-1, step=1, value=0)  # <-- match this name
)
# Out:
# interactive(children=(IntSlider(value=0, description='timestep', max=999), Output()), _dom_classes=('widget-in…
# <function network_utils.show_bump_3D(matrix, PC_idx, timestep)>
